# %%
import os
import zipfile

from tqdm import tqdm_notebook

import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

import numpy as np

from keras import backend as K
from keras import layers
from keras.preprocessing.image import load_img, img_to_array
from keras.applications import vgg16
from keras import initializers
from keras import optimizers
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model


# from utils import process_image, expand_input, get_vgg_activation, dummy_loss, zero_loss, deprocess_image
# from utils import get_padding, remove_padding
# from models import get_temp_view_model, get_training_model, get_evaluate_model
from imageio import imwrite, imsave

import time
import datetime

# %% [markdown]
# Based on: https://github.com/overflocat/fast-neural-style-keras/

# %% [markdown]
# ### Fetching data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Download COCO 2014 dataset**

# %%
# show current dir
# !pwd
# Out:
# /content

# %%
# download train part of COCO 2014 dataset to content folder
# !wget http://images.cocodataset.org/zips/train2014.zip

# create dir for dataset and extract zip file there
! mkdir coco2014_train
# !ls
# Out:
# --2020-02-28 12:57:01--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.27.12
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.27.12|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip.1’
#
# train2014.zip.1       0%[                    ]  77.02M  13.8MB/s    eta 20m 33s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-09a72f5b0405> in <module>()
# ----> 1 get_ipython().system('wget http://images.cocodataset.org/zips/train2014.zip')
#       2
#       3 # create dir for dataset and extract zip file there
#       4 get_ipython().system(' mkdir coco2014_train')
#       5 get_ipython().system('ls')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      94       kwargs.update({'also_return_output': True})
#      95
# ---> 96     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      97
#      98     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     353
#     354   hide_args = ['cell_remove_stdin', {}]
# --> 355   _message.blocking_request(*hide_args, parent=shell.parent_header)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
dir_path = '/content/coco2014_train'
zip_file_path = '/content/train2014.zip'
unzipped_train_path = '/content/coco2014_train/train2014'

# %%
# %%time
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(dir_path)
# Out:
# CPU times: user 30 s, sys: 22.3 s, total: 52.3 s
# Wall time: 6min 21s

# %%
# create complete file pathes
files_path_list = [os.path.join(unzipped_train_path, file_name) for file_name in os.listdir(unzipped_train_path)]
files_path_list[:3]
# Out:
# ['/content/coco2014_train/train2014/COCO_train2014_000000275466.jpg',
#  '/content/coco2014_train/train2014/COCO_train2014_000000049118.jpg',
#  '/content/coco2014_train/train2014/COCO_train2014_000000064809.jpg']

# %%
print('Samples amount:', len(files_path_list))
# Out:
# Samples amount: 82783

# %%
img_example = cv2.imread(files_path_list[np.random.randint(0, len(files_path_list))])
cv2_imshow(img_example)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7FDEB0B67908>

# %% [markdown]
# ### Options

# %%
# file pathes
options = {
    "net_name": "night",

    "style_image_path": "/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/fst_loop_img/night.jpg",
    "train_image_path": dir_path,
    "test_image_path": "/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/fst_loop_img/dogs.jpg",
    "test_res_save_path": "/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/fst_loop_img/results/",

    "weights_save_path": "/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/saved_models/",
    "weights_read_path": "/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/saved_models/night.h5" 
}

# %%
# Neuralnetwork options
neuro_options = {
  "learning_rate": 1e-3,
  "content_weight": 400,
  "style_weight": 0.1,
  "total_variation_weight": 2,

  "train_image_height": 256,
  "train_image_width": 256,

  "plot_model": False,

  "content_layer": "block2_conv2",
  "style_layer": ["block1_conv2", "block2_conv2", "block3_conv3", "block4_conv3"], 

  "batch_size": 4,
  "steps_per_epoch": 20000,
  "epochs": 2,
  "test_iter": 50,
  "view_iter": 10,
}

options.update(neuro_options)

# %% [markdown]
# ### Utils

# %%
def process_image(image_path, width, height, resize=True):
    if resize:
        img = load_img(image_path, target_size=(height, width))
    else:
        img = load_img(image_path)
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg16.preprocess_input(img)
    return img


def deprocess_image(x, width, height):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, height, width))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((height, width, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x


def expand_input(batch_size, input_o):
    expanded_input = input_o.copy()
    for x in range(batch_size - 1):
        expanded_input = np.append(expanded_input, input_o, axis=0)

    return expanded_input


def get_padding(image, axis_expanded=True):
    height = image.shape[1]
    width = image.shape[2]

    pad_height = (height//8 + 1) * 8 - height
    pad_width = (width//8 + 1) * 8 - width

    if axis_expanded:
        padding = (0, 0), (0, pad_height), (0, pad_width), (0, 0)
    else:
        padding = ((0, pad_height), (0, pad_width), (0, 0))

    new_image = np.pad(image, padding, 'reflect')
    return new_image


def remove_padding(image, ori_height, ori_width):
    new_image = image[0:ori_height, 0:ori_width, :]
    return new_image


def get_vgg_activation(layer_name, width, height):
    tensor = K.placeholder((1, height, width, 3))
    model = vgg16.VGG16(input_tensor=tensor, weights='imagenet', include_top=False)
    outputs_dict = {}
    for layer in model.layers:
        outputs_dict[layer.name] = layer.output
        layer.trainable = False
    return K.function([tensor], [outputs_dict[layer_name]])


def get_content_loss(args):
    new_activation, content_activation = args[0], args[1]
    shape = K.cast(K.shape(content_activation), dtype='float32')
    return K.sum(K.square(new_activation - content_activation)) / (shape[1] * shape[2] * shape[3])


def gram_matrix(activation):
    assert K.ndim(activation) == 3
    shape = K.cast(K.shape(activation), dtype='float32')
    shape = (shape[0] * shape[1], shape[2])

    activation = K.reshape(activation, shape)
    return K.dot(K.transpose(activation), activation) / (shape[0] * shape[1])


def get_style_loss(args, **kwargs):
    batch_size = kwargs['batch_size']
    new_activation, style_activation = args[0], args[1]

    loss_sum = K.variable(0.0)
    for i in range(batch_size):
        ori_gram_matrix = gram_matrix(style_activation[i])
        new_gram_matrix = gram_matrix(new_activation[i])
        loss_sum = loss_sum + K.sum(K.square(ori_gram_matrix - new_gram_matrix))
    return loss_sum


def get_tv_loss(args, **kwargs):
    image = args[0]
    width = kwargs['width']
    height = kwargs['height']
    x_diff = K.square(image[:, :height - 1, :, :] - image[:, 1:, :, :])
    y_diff = K.square(image[:, :, :width - 1, :] - image[:, :, 1:, :])
    x_diff = K.sum(x_diff) / height
    y_diff = K.sum(y_diff) / width
    return x_diff + y_diff


def residual_block(x, num):
    shortcut = x
    x = layers.Conv2D(128, (3, 3), strides=1, padding='same', name='resi_conv_%d_1' % num)(x)
    x = layers.BatchNormalization(name='resi_normal_%d_1' % num)(x)
    x = layers.Activation('relu', name='resi_relu_%d_1' % num)(x)
    x = layers.Conv2D(128, (3, 3), strides=1, padding='same', name='resi_conv_%d_2' % num)(x)
    x = layers.BatchNormalization(name='resi_normal_%d_2' % num)(x)
    m = layers.add([x, shortcut], name='resi_add_%d' % num)
    return m


def dummy_loss(y_true, y_pred):
    return y_pred


def zero_loss(y_true, y_pred):
    return K.variable(np.zeros(1,))

# %%
class OutputScale(layers.Layer):

    def __init__(self, **kwargs):
        super(OutputScale, self).__init__(**kwargs)

    def build(self, input_shape):
        pass

    def call(self, x, mask=None):
        return x * 150

    def compute_output_shape(self, input_shape):
        return input_shape


class AverageAddTwo(layers.Layer):

    def __init__(self, **kwargs):
        super(AverageAddTwo, self).__init__(**kwargs)

    def build(self, input_shape):
        pass

    def call(self, x, mask=None):
        return x[0] / 2 + x[1] / 2

    def compute_output_shape(self, input_shape):
        return input_shape


class InputReflect(layers.Layer):

    def __init__(self, width, height, **kwargs):
        super(InputReflect, self).__init__(**kwargs)
        self.width = width
        self.height = height

    def build(self, input_shape):
        init = initializers.RandomUniform(minval=-50, maxval=50, seed=None)
        self.kernel = self.add_weight(name='kernel', shape=(self.height, self.width, 3),
                                      initializer=init, trainable=True)

        super(InputReflect, self).build(input_shape)

    def call(self, x, mask=None):
        y = x * self.kernel
        return y

    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# ### Setting up model

# %%
def get_training_model(width, height, bs=1, bi_style=False):
    input_o = layers.Input(shape=(height, width, 3), dtype='float32', name='input_o')

    c1 = layers.Conv2D(32, (9, 9), strides=1, padding='same', name='conv_1')(input_o)
    c1 = layers.BatchNormalization(name='normal_1')(c1)
    c1 = layers.Activation('relu', name='relu_1')(c1)

    c2 = layers.Conv2D(64, (3, 3), strides=2, padding='same', name='conv_2')(c1)
    c2 = layers.BatchNormalization(name='normal_2')(c2)
    c2 = layers.Activation('relu', name='relu_2')(c2)

    c3 = layers.Conv2D(128, (3, 3), strides=2, padding='same', name='conv_3')(c2)
    c3 = layers.BatchNormalization(name='normal_3')(c3)
    c3 = layers.Activation('relu', name='relu_3')(c3)

    r1 = residual_block(c3, 1)
    r2 = residual_block(r1, 2)
    r3 = residual_block(r2, 3)
    r4 = residual_block(r3, 4)
    r5 = residual_block(r4, 5)

    d1 = layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same', name='conv_4')(r5)
    d1 = layers.BatchNormalization(name='normal_4')(d1)
    d1 = layers.Activation('relu', name='relu_4')(d1)

    d2 = layers.Conv2DTranspose(32, (3, 3), strides=2, padding='same', name='conv_5')(d1)
    d2 = layers.BatchNormalization(name='normal_5')(d2)
    d2 = layers.Activation('relu', name='relu_5')(d2)

    c4 = layers.Conv2D(3, (9, 9), strides=1, padding='same', name='conv_6')(d2)
    c4 = layers.BatchNormalization(name='normal_6')(c4)
    c4 = layers.Activation('tanh', name='tanh_1')(c4)
    c4 = OutputScale(name='output')(c4)

    content_activation = layers.Input(shape=(height // 2, width // 2, 128), dtype='float32')
    style_activation1 = layers.Input(shape=(height, width, 64), dtype='float32')
    style_activation2 = layers.Input(shape=(height // 2, width // 2, 128), dtype='float32')
    style_activation3 = layers.Input(shape=(height // 4, width // 4, 256), dtype='float32')
    style_activation4 = layers.Input(shape=(height // 8, width // 8, 512), dtype='float32')

    if bi_style:
        style_activation1_2 = layers.Input(shape=(height, width, 64), dtype='float32')
        style_activation2_2 = layers.Input(shape=(height // 2, width // 2, 128), dtype='float32')
        style_activation3_2 = layers.Input(shape=(height // 4, width // 4, 256), dtype='float32')
        style_activation4_2 = layers.Input(shape=(height // 8, width // 8, 512), dtype='float32')

    total_variation_loss = layers.Lambda(get_tv_loss, output_shape=(1,), name='tv',
                                         arguments={'width': width, 'height': height})([c4])

    # Block 1
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(c4)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    style_loss1 = layers.Lambda(get_style_loss, output_shape=(1,),
                                name='style1', arguments={'batch_size': bs})([x, style_activation1])
    if bi_style:
        style_loss1_2 = layers.Lambda(get_style_loss, output_shape=(1,),
                                    name='style1_2', arguments={'batch_size': bs})([x, style_activation1_2])
        style_loss1 = AverageAddTwo(name='style1_out')([style_loss1, style_loss1_2])
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    content_loss = layers.Lambda(get_content_loss, output_shape=(1,), name='content')([x, content_activation])
    style_loss2 = layers.Lambda(get_style_loss, output_shape=(1,),
                                name='style2', arguments={'batch_size': bs})([x, style_activation2])
    if bi_style:
        style_loss2_2 = layers.Lambda(get_style_loss, output_shape=(1,),
                                    name='style2_2', arguments={'batch_size': bs})([x, style_activation2_2])
        style_loss2 = AverageAddTwo(name='style2_out')([style_loss2, style_loss2_2])
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    style_loss3 = layers.Lambda(get_style_loss, output_shape=(1,),
                                name='style3', arguments={'batch_size': bs})([x, style_activation3])
    if bi_style:
        style_loss3_2 = layers.Lambda(get_style_loss, output_shape=(1,),
                                    name='style3_2', arguments={'batch_size': bs})([x, style_activation3_2])
        style_loss3 = AverageAddTwo(name='style3_out')([style_loss3, style_loss3_2])
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    style_loss4 = layers.Lambda(get_style_loss, output_shape=(1,),
                                name='style4', arguments={'batch_size': bs})([x, style_activation4])
    if bi_style:
        style_loss4_2 = layers.Lambda(get_style_loss, output_shape=(1,),
                                    name='style4_2', arguments={'batch_size': bs})([x, style_activation4_2])
        style_loss4 = AverageAddTwo(name='style4_out')([style_loss4, style_loss4_2])
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    if bi_style:
        model = Model(
            [input_o, content_activation, style_activation1, style_activation2, style_activation3, style_activation4,
             style_activation1_2, style_activation2_2, style_activation3_2, style_activation4_2],
            [content_loss, style_loss1, style_loss2, style_loss3, style_loss4, total_variation_loss, c4])
    else:
        model = Model(
            [input_o, content_activation, style_activation1, style_activation2, style_activation3, style_activation4],
            [content_loss, style_loss1, style_loss2, style_loss3, style_loss4, total_variation_loss, c4])
    model_layers = {layer.name: layer for layer in model.layers}
    original_vgg = vgg16.VGG16(weights='imagenet', include_top=False)
    original_vgg_layers = {layer.name: layer for layer in original_vgg.layers}

    # load image_net weight
    for layer in original_vgg.layers:
        if layer.name in model_layers:
            model_layers[layer.name].set_weights(original_vgg_layers[layer.name].get_weights())
            model_layers[layer.name].trainable = False

    print("training model built successfully!")
    return model

# %%
# Model = get_training_model(width = options['train_image_width'], 
#                            height = options['train_image_height'], 
#                            bs=1, 
#                            bi_style=False)

# %% [markdown]
# ### Training

# %%
def train(options):
    width = options["train_image_width"]
    height = options["train_image_height"]

    # Get style activations
    style_tensor = process_image(options["style_image_path"], width, height)
    style_acts = list()
    for layer_name in options["style_layer"]:
        func = get_vgg_activation(layer_name, width, height)
        style_act = expand_input(options["batch_size"], func([style_tensor])[0])
        style_acts.append(style_act)

    if "style_image_path_2" in options:
        style_tensor_2 = process_image(options["style_image_path_2"], width, height)
        style_acts_2 = list()
        for layer_name in options["style_layer"]:
            func = get_vgg_activation(layer_name, width, height)
            style_act_2 = expand_input(options["batch_size"], func([style_tensor_2])[0])
            style_acts_2.append(style_act_2)

    # Get content activations for test_image
    content_test = process_image(options["test_image_path"], width, height)
    content_func = get_vgg_activation(options["content_layer"], width, height)
    content_act_test = expand_input(options["batch_size"], content_func([content_test])[0])
    content_test = expand_input(options["batch_size"], content_test)

    # Get weights
    style_w = options["style_weight"] / len(style_acts)
    content_w = options["content_weight"]
    tv_w = options["total_variation_weight"]

    # Get training model
    bi_style = False
    if "style_image_path_2" in options:
        bi_style = True
    training_model = get_training_model(width, height, bs=options['batch_size'], bi_style=bi_style)
    if bi_style:
        training_model.compile(loss={'content': dummy_loss, 'style1_out': dummy_loss, 'style2_out': dummy_loss,
                                     'style3_out': dummy_loss, 'style4_out': dummy_loss, 'tv': dummy_loss,
                                     'output': zero_loss},
                               optimizer=optimizers.Adam(lr=options["learning_rate"]),
                               loss_weights=[content_w, style_w, style_w, style_w, style_w, tv_w, 0])
    else:
        training_model.compile(loss={'content': dummy_loss, 'style1': dummy_loss, 'style2': dummy_loss,
                                     'style3': dummy_loss, 'style4': dummy_loss, 'tv': dummy_loss, 'output': zero_loss},
                               optimizer=optimizers.Adam(lr=options["learning_rate"]),
                               loss_weights=[content_w, style_w, style_w, style_w, style_w, tv_w, 0])

    # If flag is set, print model summary and generate model description
    if options["plot_model"]:
        training_model.summary()
        plot_model(training_model, to_file='model.png')

    # function for printing test information
    def print_test_results(cur_res, cur_iter, prev_loss):
        losses = list()
        losses.append(cur_res[0][0] * content_w)
        losses.append(cur_res[1][0] * style_w)
        losses.append(cur_res[2][0] * style_w)
        losses.append(cur_res[3][0] * style_w)
        losses.append(cur_res[4][0] * style_w)
        losses.append(cur_res[5][0] * tv_w)
        cur_loss = sum(losses)
        if prev_loss is None:
            prev_loss = cur_loss

        print("----------------------------------------------------")
        print("Details: iteration %d, " % cur_iter, end='')
        print('improvement: %.2f percent, ' % ((prev_loss - cur_loss) / prev_loss * 100), end='')
        print("loss: %.0f" % cur_loss)
        print("content_loss: %.0f, style_loss_1: %.0f, style_loss_2: %.0f\n"
              "style_loss_3: %.0f, style_loss_4: %.0f, tv_loss: %.0f"
              % (losses[0], losses[1], losses[2], losses[3], losses[4], losses[5]))
        print("----------------------------------------------------")

        return cur_loss

    # Prepare for training
    dg = ImageDataGenerator()
    dummy_in = expand_input(options["batch_size"], np.array([0.0]))
    interrupted = False
    c_loss = None
    t_sum = 0.0

    # Begin Training
    t_total_1 = time.time()
    for i in range(options["epochs"]):
        print("Epoch: %d" % (i+1))
        iters = 0

        for x in dg.flow_from_directory(options["train_image_path"], class_mode=None,
                                        batch_size=options["batch_size"], target_size=(height, width)):
            try:
                t1 = time.time()
                x = vgg16.preprocess_input(x)
                content_act = content_func([x])[0]
                if bi_style:
                    res = training_model.fit([x, content_act, style_acts[0], style_acts[1], style_acts[2],
                                              style_acts[3], style_acts_2[0], style_acts_2[1], style_acts_2[2],
                                              style_acts_2[3]], [dummy_in, dummy_in, dummy_in, dummy_in, dummy_in,
                                                                 dummy_in, x],
                                             epochs=1, verbose=0, batch_size=options["batch_size"])
                else:
                    res = training_model.fit([x, content_act, style_acts[0], style_acts[1], style_acts[2],
                                              style_acts[3]], [dummy_in, dummy_in, dummy_in, dummy_in, dummy_in,
                                                               dummy_in, x],
                                             epochs=1, verbose=0, batch_size=options["batch_size"])
                t2 = time.time()
                t_sum += t2 - t1

                iters += 1

                if iters % options["view_iter"] == 0:
                    loss = res.history['loss'][0]
                    est_time = int((options["steps_per_epoch"]*(options["epochs"]-i) - iters)
                                   * (t_sum/options["view_iter"]))
                    print("Iter : %d / %d, Time elapsed: %0.2f seconds, Loss: %.0f, EST: " %
                          (iters, options["steps_per_epoch"], t_sum/options["view_iter"], loss) +
                          str(datetime.timedelta(seconds=est_time)))
                    t_sum = 0.0

                if iters % options["test_iter"] == 0:
                    if bi_style:
                        res = training_model.predict([content_test, content_act_test, style_acts[0], style_acts[1],
                                                      style_acts[2], style_acts[3], style_acts_2[0], style_acts_2[1],
                                                      style_acts_2[2], style_acts_2[3]])
                    else:
                        res = training_model.predict([content_test, content_act_test, style_acts[0], style_acts[1],
                                                      style_acts[2], style_acts[3]])
                    c_loss = print_test_results(res, iters, c_loss)

                    output = deprocess_image(res[6][0], width, height)
                    imsave(options["test_res_save_path"] + '%d_%d_output.jpg' % (i, iters), output)

                if iters >= options["steps_per_epoch"]:
                    break

            except KeyboardInterrupt:
                print("Interrupted, training suspended.")
                interrupted = True
                break

        if interrupted:
            break

    t_total_2 = time.time()
    print("Training ended. Time used: " + str(datetime.timedelta(seconds=int(t_total_2-t_total_1))))

    # Saving models
    print("Saving models...")
    model_eval = get_evaluate_model(width, height)
    training_model_layers = {layer.name: layer for layer in training_model.layers}
    for layer in model_eval.layers:
        if layer.name in training_model_layers:
            print(layer.name)
            layer.set_weights(training_model_layers[layer.name].get_weights())

    model_eval.save_weights(options["weights_save_path"] + '%s_weights.h5' % options["net_name"])

# %%
train(options)
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------------------------
# Details: iteration 15050, improvement: 2.91 percent, loss: 613212873
# content_loss: 468145050, style_loss_1: 2971764, style_loss_2: 41557722
# style_loss_3: 83695162, style_loss_4: 265303, tv_loss: 16577873
# ----------------------------------------------------
# Iter : 15060 / 20000, Time elapsed: 0.33 seconds, Loss: 584628928, EST: 2:16:27
# Iter : 15070 / 20000, Time elapsed: 0.33 seconds, Loss: 582469440, EST: 2:17:16
# Iter : 15080 / 20000, Time elapsed: 0.33 seconds, Loss: 627902912, EST: 2:17:42
# Iter : 15090 / 20000, Time elapsed: 0.33 seconds, Loss: 628267328, EST: 2:16:54
# Iter : 15100 / 20000, Time elapsed: 0.33 seconds, Loss: 599640192, EST: 2:17:17
# ----------------------------------------------------
# Details: iteration 15100, improvement: -2.53 percent, loss: 628700267
# content_loss: 444163300, style_loss_1: 7040476, style_loss_2: 76861491
# style_loss_3: 84941805, style_loss_4: 232485, tv_loss: 15460710
# ----------------------------------------------------
# Iter : 15110 / 20000, Time elapsed: 0.33 seconds, Loss: 530926272, EST: 2:16:26
# Iter : 15120 / 20000, Time elapsed: 0.33 seconds, Loss: 560077696, EST: 2:17:04
# Iter : 15130 / 20000, Time elapsed: 0.33 seconds, Loss: 552866048, EST: 2:17:18
# Iter : 15140 / 20000, Time elapsed: 0.33 seconds, Loss: 586054720, EST: 2:17:16
# Iter : 15150 / 20000, Time elapsed: 0.33 seconds, Loss: 504838656, EST: 2:17:17
# ----------------------------------------------------
# Details: iteration 15150, improvement: 1.97 percent, loss: 616299040
# content_loss: 471280450, style_loss_1: 2280233, style_loss_2: 39047459
# style_loss_3: 86538675, style_loss_4: 254991, tv_loss: 16897232
# ----------------------------------------------------
# Iter : 15160 / 20000, Time elapsed: 0.33 seconds, Loss: 583136064, EST: 2:16:57
# Iter : 15170 / 20000, Time elapsed: 0.33 seconds, Loss: 537106368, EST: 2:15:44
# Iter : 15180 / 20000, Time elapsed: 0.33 seconds, Loss: 593547072, EST: 2:16:56
# Iter : 15190 / 20000, Time elapsed: 0.33 seconds, Loss: 602052480, EST: 2:16:48
# Iter : 15200 / 20000, Time elapsed: 0.33 seconds, Loss: 661257984, EST: 2:17:33
# ----------------------------------------------------
# Details: iteration 15200, improvement: -23.57 percent, loss: 761584465
# content_loss: 477732900, style_loss_1: 20669386, style_loss_2: 100129203
# style_loss_3: 146633830, style_loss_4: 264358, tv_loss: 16154788
# ----------------------------------------------------
# Iter : 15210 / 20000, Time elapsed: 0.33 seconds, Loss: 547007616, EST: 2:16:19
# Iter : 15220 / 20000, Time elapsed: 0.33 seconds, Loss: 690966912, EST: 2:16:27
# Iter : 15230 / 20000, Time elapsed: 0.33 seconds, Loss: 605184640, EST: 2:15:44
# Iter : 15240 / 20000, Time elapsed: 0.33 seconds, Loss: 515836032, EST: 2:15:35
# Iter : 15250 / 20000, Time elapsed: 0.33 seconds, Loss: 626886528, EST: 2:15:35
# ----------------------------------------------------
# Details: iteration 15250, improvement: 14.72 percent, loss: 649470067
# content_loss: 473326800, style_loss_1: 3648134, style_loss_2: 57199360
# style_loss_3: 97371059, style_loss_4: 285340, tv_loss: 17639374
# ----------------------------------------------------
# Iter : 15260 / 20000, Time elapsed: 0.33 seconds, Loss: 634134080, EST: 2:15:50
# Iter : 15270 / 20000, Time elapsed: 0.33 seconds, Loss: 574787584, EST: 2:14:54
# Iter : 15280 / 20000, Time elapsed: 0.33 seconds, Loss: 575757952, EST: 2:16:44
# Iter : 15290 / 20000, Time elapsed: 0.33 seconds, Loss: 554159424, EST: 2:15:51
# Iter : 15300 / 20000, Time elapsed: 0.33 seconds, Loss: 597815936, EST: 2:15:38
# ----------------------------------------------------
# Details: iteration 15300, improvement: 0.74 percent, loss: 644693882
# content_loss: 473897350, style_loss_1: 4068614, style_loss_2: 54523290
# style_loss_3: 94933939, style_loss_4: 256307, tv_loss: 17014382
# ----------------------------------------------------
# Iter : 15310 / 20000, Time elapsed: 0.33 seconds, Loss: 637487040, EST: 2:16:08
# Iter : 15320 / 20000, Time elapsed: 0.33 seconds, Loss: 587129408, EST: 2:16:07
# Iter : 15330 / 20000, Time elapsed: 0.33 seconds, Loss: 634272192, EST: 2:15:13
# Iter : 15340 / 20000, Time elapsed: 0.33 seconds, Loss: 604118784, EST: 2:15:36
# Iter : 15350 / 20000, Time elapsed: 0.33 seconds, Loss: 601389760, EST: 2:15:57
# ----------------------------------------------------
# Details: iteration 15350, improvement: 5.11 percent, loss: 611761701
# content_loss: 450440850, style_loss_1: 3676476, style_loss_2: 63943360
# style_loss_3: 76325798, style_loss_4: 230504, tv_loss: 17144712
# ----------------------------------------------------
# Iter : 15360 / 20000, Time elapsed: 0.33 seconds, Loss: 578561728, EST: 2:16:04
# Iter : 15370 / 20000, Time elapsed: 0.33 seconds, Loss: 504302080, EST: 2:15:29
# Iter : 15380 / 20000, Time elapsed: 0.33 seconds, Loss: 596073600, EST: 2:14:35
# Iter : 15390 / 20000, Time elapsed: 0.33 seconds, Loss: 566735744, EST: 2:15:30
# Iter : 15400 / 20000, Time elapsed: 0.33 seconds, Loss: 589874048, EST: 2:15:25
# ----------------------------------------------------
# Details: iteration 15400, improvement: -0.38 percent, loss: 614094336
# content_loss: 476020500, style_loss_1: 5204330, style_loss_2: 38871251
# style_loss_3: 77383680, style_loss_4: 265116, tv_loss: 16349459
# ----------------------------------------------------
# Iter : 15410 / 20000, Time elapsed: 0.33 seconds, Loss: 593484224, EST: 2:15:22
# Iter : 15420 / 20000, Time elapsed: 0.33 seconds, Loss: 640967232, EST: 2:15:15
# Iter : 15430 / 20000, Time elapsed: 0.33 seconds, Loss: 599965056, EST: 2:15:01
# Iter : 15440 / 20000, Time elapsed: 0.33 seconds, Loss: 613653184, EST: 2:14:57
# Iter : 15450 / 20000, Time elapsed: 0.33 seconds, Loss: 610475840, EST: 2:14:48
# ----------------------------------------------------
# Details: iteration 15450, improvement: 1.02 percent, loss: 607808768
# content_loss: 448639900, style_loss_1: 4382204, style_loss_2: 57422291
# style_loss_3: 80774182, style_loss_4: 241660, tv_loss: 16348530
# ----------------------------------------------------
# Iter : 15460 / 20000, Time elapsed: 0.33 seconds, Loss: 550495168, EST: 2:16:07
# Iter : 15470 / 20000, Time elapsed: 0.33 seconds, Loss: 526717056, EST: 2:15:47
# Iter : 15480 / 20000, Time elapsed: 0.33 seconds, Loss: 590975744, EST: 2:14:43
# Iter : 15490 / 20000, Time elapsed: 0.33 seconds, Loss: 514004800, EST: 2:14:13
# Iter : 15500 / 20000, Time elapsed: 0.33 seconds, Loss: 604824640, EST: 2:14:27
# ----------------------------------------------------
# Details: iteration 15500, improvement: -2.11 percent, loss: 620662961
# content_loss: 440392450, style_loss_1: 4902186, style_loss_2: 60632544
# style_loss_3: 97311622, style_loss_4: 269648, tv_loss: 17154510
# ----------------------------------------------------
# Iter : 15510 / 20000, Time elapsed: 0.33 seconds, Loss: 618421504, EST: 2:14:14
# Iter : 15520 / 20000, Time elapsed: 0.33 seconds, Loss: 578327744, EST: 2:15:28
# Iter : 15530 / 20000, Time elapsed: 0.33 seconds, Loss: 548557632, EST: 2:14:48
# Iter : 15540 / 20000, Time elapsed: 0.33 seconds, Loss: 551964416, EST: 2:14:19
# Iter : 15550 / 20000, Time elapsed: 0.33 seconds, Loss: 640301760, EST: 2:13:44
# ----------------------------------------------------
# Details: iteration 15550, improvement: 1.76 percent, loss: 609742339
# content_loss: 434527650, style_loss_1: 4039602, style_loss_2: 65018803
# style_loss_3: 89573658, style_loss_4: 251147, tv_loss: 16331479
# ----------------------------------------------------
# Iter : 15560 / 20000, Time elapsed: 0.33 seconds, Loss: 542976192, EST: 2:14:23
# Iter : 15570 / 20000, Time elapsed: 0.33 seconds, Loss: 588272512, EST: 2:13:56
# Iter : 15580 / 20000, Time elapsed: 0.33 seconds, Loss: 586237888, EST: 2:13:43
# Iter : 15590 / 20000, Time elapsed: 0.33 seconds, Loss: 534495168, EST: 2:14:50
# Iter : 15600 / 20000, Time elapsed: 0.33 seconds, Loss: 549637312, EST: 2:15:57
# ----------------------------------------------------
# Details: iteration 15600, improvement: -2.67 percent, loss: 626052417
# content_loss: 435609200, style_loss_1: 5903224, style_loss_2: 73381517
# style_loss_3: 94283866, style_loss_4: 253288, tv_loss: 16621323
# ----------------------------------------------------
# Iter : 15610 / 20000, Time elapsed: 0.33 seconds, Loss: 607892864, EST: 2:14:30
# Iter : 15620 / 20000, Time elapsed: 0.33 seconds, Loss: 655531776, EST: 2:14:08
# Iter : 15630 / 20000, Time elapsed: 0.33 seconds, Loss: 573863360, EST: 2:13:07
# Iter : 15640 / 20000, Time elapsed: 0.33 seconds, Loss: 524949536, EST: 2:13:58
# Iter : 15650 / 20000, Time elapsed: 0.33 seconds, Loss: 598885440, EST: 2:13:00
# ----------------------------------------------------
# Details: iteration 15650, improvement: 3.70 percent, loss: 602906266
# content_loss: 446675900, style_loss_1: 4261627, style_loss_2: 50454262
# style_loss_3: 85576653, style_loss_4: 263208, tv_loss: 15674615
# ----------------------------------------------------
# Iter : 15660 / 20000, Time elapsed: 0.33 seconds, Loss: 527085088, EST: 2:13:51
# Iter : 15670 / 20000, Time elapsed: 0.33 seconds, Loss: 596741504, EST: 2:13:00
# Iter : 15680 / 20000, Time elapsed: 0.33 seconds, Loss: 541814400, EST: 2:14:26
# Iter : 15690 / 20000, Time elapsed: 0.33 seconds, Loss: 608622912, EST: 2:13:30
# Iter : 15700 / 20000, Time elapsed: 0.33 seconds, Loss: 539141696, EST: 2:13:17
# ----------------------------------------------------
# Details: iteration 15700, improvement: -4.49 percent, loss: 629984826
# content_loss: 444227350, style_loss_1: 4500625, style_loss_2: 66749005
# style_loss_3: 97949510, style_loss_4: 276232, tv_loss: 16282104
# ----------------------------------------------------
# Iter : 15710 / 20000, Time elapsed: 0.33 seconds, Loss: 594616256, EST: 2:13:40
# Iter : 15720 / 20000, Time elapsed: 0.33 seconds, Loss: 615070976, EST: 2:13:24
# Iter : 15730 / 20000, Time elapsed: 0.33 seconds, Loss: 624213632, EST: 2:12:51
# Iter : 15740 / 20000, Time elapsed: 0.33 seconds, Loss: 545392128, EST: 2:12:57
# Iter : 15750 / 20000, Time elapsed: 0.33 seconds, Loss: 525246112, EST: 2:12:34
# ----------------------------------------------------
# Details: iteration 15750, improvement: 3.97 percent, loss: 604971401
# content_loss: 452622200, style_loss_1: 5196248, style_loss_2: 49957555
# style_loss_3: 80504813, style_loss_4: 247532, tv_loss: 16443053
# ----------------------------------------------------
# Iter : 15760 / 20000, Time elapsed: 0.33 seconds, Loss: 666882944, EST: 2:13:10
# Iter : 15770 / 20000, Time elapsed: 0.33 seconds, Loss: 573888640, EST: 2:13:18
# Iter : 15780 / 20000, Time elapsed: 0.33 seconds, Loss: 541010496, EST: 2:12:47
# Iter : 15790 / 20000, Time elapsed: 0.33 seconds, Loss: 571053248, EST: 2:12:45
# Iter : 15800 / 20000, Time elapsed: 0.33 seconds, Loss: 557936768, EST: 2:13:18
# ----------------------------------------------------
# Details: iteration 15800, improvement: -2.30 percent, loss: 618872983
# content_loss: 459431700, style_loss_1: 3486723, style_loss_2: 51815552
# style_loss_3: 86388915, style_loss_4: 253409, tv_loss: 17496684
# ----------------------------------------------------
# Iter : 15810 / 20000, Time elapsed: 0.33 seconds, Loss: 544850496, EST: 2:13:41
# Iter : 15820 / 20000, Time elapsed: 0.33 seconds, Loss: 577961728, EST: 2:12:52
# Iter : 15830 / 20000, Time elapsed: 0.33 seconds, Loss: 613312320, EST: 2:12:56
# Iter : 15840 / 20000, Time elapsed: 0.33 seconds, Loss: 609664384, EST: 2:11:44
# Iter : 15850 / 20000, Time elapsed: 0.33 seconds, Loss: 583373376, EST: 2:12:35
# ----------------------------------------------------
# Details: iteration 15850, improvement: 4.65 percent, loss: 590117684
# content_loss: 446678400, style_loss_1: 3367976, style_loss_2: 49646752
# style_loss_3: 74814656, style_loss_4: 242004, tv_loss: 15367896
# ----------------------------------------------------
# Iter : 15860 / 20000, Time elapsed: 0.33 seconds, Loss: 564623040, EST: 2:13:01
# Iter : 15870 / 20000, Time elapsed: 0.33 seconds, Loss: 573484416, EST: 2:13:00
# Iter : 15880 / 20000, Time elapsed: 0.33 seconds, Loss: 645183488, EST: 2:12:59
# Iter : 15890 / 20000, Time elapsed: 0.33 seconds, Loss: 614653440, EST: 2:12:18
# Iter : 15900 / 20000, Time elapsed: 0.33 seconds, Loss: 584895936, EST: 2:12:00
# ----------------------------------------------------
# Details: iteration 15900, improvement: -7.30 percent, loss: 633209976
# content_loss: 432399650, style_loss_1: 5017428, style_loss_2: 85485280
# style_loss_3: 94258010, style_loss_4: 271129, tv_loss: 15778480
# ----------------------------------------------------
# Iter : 15910 / 20000, Time elapsed: 0.33 seconds, Loss: 592404096, EST: 2:11:46
# Iter : 15920 / 20000, Time elapsed: 0.33 seconds, Loss: 546002368, EST: 2:12:29
# Iter : 15930 / 20000, Time elapsed: 0.33 seconds, Loss: 640943360, EST: 2:13:04
# Iter : 15940 / 20000, Time elapsed: 0.33 seconds, Loss: 534117472, EST: 2:12:06
# Iter : 15950 / 20000, Time elapsed: 0.33 seconds, Loss: 582258304, EST: 2:11:31
# ----------------------------------------------------
# Details: iteration 15950, improvement: -6.11 percent, loss: 671886362
# content_loss: 469222650, style_loss_1: 2898783, style_loss_2: 65594810
# style_loss_3: 116559155, style_loss_4: 252034, tv_loss: 17358930
# ----------------------------------------------------
# Iter : 15960 / 20000, Time elapsed: 0.33 seconds, Loss: 547876800, EST: 2:12:43
# Iter : 15970 / 20000, Time elapsed: 0.33 seconds, Loss: 561617920, EST: 2:13:05
# Iter : 15980 / 20000, Time elapsed: 0.33 seconds, Loss: 654891008, EST: 2:12:03
# Iter : 15990 / 20000, Time elapsed: 0.33 seconds, Loss: 504401728, EST: 2:11:21
# Iter : 16000 / 20000, Time elapsed: 0.33 seconds, Loss: 540823104, EST: 2:11:16
# ----------------------------------------------------
# Details: iteration 16000, improvement: 9.29 percent, loss: 609455647
# content_loss: 432042600, style_loss_1: 7608298, style_loss_2: 64568704
# style_loss_3: 89027853, style_loss_4: 250849, tv_loss: 15957344
# ----------------------------------------------------
# Iter : 16010 / 20000, Time elapsed: 0.33 seconds, Loss: 560743104, EST: 2:12:27
# Iter : 16020 / 20000, Time elapsed: 0.33 seconds, Loss: 627499456, EST: 2:11:02
# Iter : 16030 / 20000, Time elapsed: 0.33 seconds, Loss: 639325248, EST: 2:11:17
# Iter : 16040 / 20000, Time elapsed: 0.33 seconds, Loss: 612723200, EST: 2:11:39
# Iter : 16050 / 20000, Time elapsed: 0.33 seconds, Loss: 643932288, EST: 2:11:36
# ----------------------------------------------------
# Details: iteration 16050, improvement: -5.94 percent, loss: 645638140
# content_loss: 471595250, style_loss_1: 2082200, style_loss_2: 55589274
# style_loss_3: 99759424, style_loss_4: 247690, tv_loss: 16364302
# ----------------------------------------------------
# Iter : 16060 / 20000, Time elapsed: 0.33 seconds, Loss: 608218624, EST: 2:11:37
# Iter : 16070 / 20000, Time elapsed: 0.33 seconds, Loss: 563592000, EST: 2:11:21
# Iter : 16080 / 20000, Time elapsed: 0.33 seconds, Loss: 569861824, EST: 2:11:23
# Iter : 16090 / 20000, Time elapsed: 0.33 seconds, Loss: 553101120, EST: 2:11:49
# Iter : 16100 / 20000, Time elapsed: 0.33 seconds, Loss: 686291712, EST: 2:10:52
# ----------------------------------------------------
# Details: iteration 16100, improvement: 1.53 percent, loss: 635760912
# content_loss: 442070850, style_loss_1: 7743000, style_loss_2: 73815795
# style_loss_3: 96740659, style_loss_4: 299950, tv_loss: 15090658
# ----------------------------------------------------
# Iter : 16110 / 20000, Time elapsed: 0.33 seconds, Loss: 522314880, EST: 2:11:14
# Iter : 16120 / 20000, Time elapsed: 0.33 seconds, Loss: 588329216, EST: 2:10:48
# Iter : 16130 / 20000, Time elapsed: 0.33 seconds, Loss: 570188672, EST: 2:11:36
# Iter : 16140 / 20000, Time elapsed: 0.33 seconds, Loss: 505090880, EST: 2:11:04
# Iter : 16150 / 20000, Time elapsed: 0.33 seconds, Loss: 633738944, EST: 2:10:30
# ----------------------------------------------------
# Details: iteration 16150, improvement: -461.09 percent, loss: 3567213224
# content_loss: 584164550, style_loss_1: 110224870, style_loss_2: 787219610
# style_loss_3: 2030892237, style_loss_4: 535650, tv_loss: 54176308
# ----------------------------------------------------
# Iter : 16160 / 20000, Time elapsed: 0.33 seconds, Loss: 812965184, EST: 2:11:05
# Iter : 16170 / 20000, Time elapsed: 0.33 seconds, Loss: 688074112, EST: 2:11:50
# Iter : 16180 / 20000, Time elapsed: 0.33 seconds, Loss: 779411008, EST: 2:10:55
# Iter : 16190 / 20000, Time elapsed: 0.33 seconds, Loss: 728005952, EST: 2:11:14
# Iter : 16200 / 20000, Time elapsed: 0.33 seconds, Loss: 586917184, EST: 2:10:46
# ----------------------------------------------------
# Details: iteration 16200, improvement: 3.16 percent, loss: 3454534912
# content_loss: 585850800, style_loss_1: 68071603, style_loss_2: 623264000
# style_loss_3: 2122546176, style_loss_4: 491733, tv_loss: 54310600
# ----------------------------------------------------
# Iter : 16210 / 20000, Time elapsed: 0.33 seconds, Loss: 667665600, EST: 2:10:37
# Iter : 16220 / 20000, Time elapsed: 0.33 seconds, Loss: 663687040, EST: 2:09:57
# Iter : 16230 / 20000, Time elapsed: 0.33 seconds, Loss: 691897472, EST: 2:10:26
# Iter : 16240 / 20000, Time elapsed: 0.33 seconds, Loss: 579565952, EST: 2:10:57
# Iter : 16250 / 20000, Time elapsed: 0.33 seconds, Loss: 647414784, EST: 2:10:22
# ----------------------------------------------------
# Details: iteration 16250, improvement: 73.66 percent, loss: 909945370
# content_loss: 441376100, style_loss_1: 7931357, style_loss_2: 180343949
# style_loss_3: 263528602, style_loss_4: 305407, tv_loss: 16459956
# ----------------------------------------------------
# Iter : 16260 / 20000, Time elapsed: 0.33 seconds, Loss: 590022144, EST: 2:10:25
# Iter : 16270 / 20000, Time elapsed: 0.33 seconds, Loss: 655317504, EST: 2:10:23
# Iter : 16280 / 20000, Time elapsed: 0.33 seconds, Loss: 625432640, EST: 2:09:57
# Iter : 16290 / 20000, Time elapsed: 0.33 seconds, Loss: 623887936, EST: 2:11:22
# Iter : 16300 / 20000, Time elapsed: 0.33 seconds, Loss: 628927488, EST: 2:10:06
# ----------------------------------------------------
# Details: iteration 16300, improvement: 21.83 percent, loss: 711307528
# content_loss: 452484000, style_loss_1: 4547890, style_loss_2: 100835053
# style_loss_3: 137249971, style_loss_4: 251460, tv_loss: 15939153
# ----------------------------------------------------
# Iter : 16310 / 20000, Time elapsed: 0.33 seconds, Loss: 695982976, EST: 2:10:27
# Iter : 16320 / 20000, Time elapsed: 0.33 seconds, Loss: 600796224, EST: 2:09:19
# Iter : 16330 / 20000, Time elapsed: 0.33 seconds, Loss: 569985280, EST: 2:10:31
# Iter : 16340 / 20000, Time elapsed: 0.33 seconds, Loss: 619409984, EST: 2:09:17
# Iter : 16350 / 20000, Time elapsed: 0.33 seconds, Loss: 638859456, EST: 2:10:33
# ----------------------------------------------------
# Details: iteration 16350, improvement: 4.81 percent, loss: 677092840
# content_loss: 448528250, style_loss_1: 4886473, style_loss_2: 97272115
# style_loss_3: 111361664, style_loss_4: 231948, tv_loss: 14812390
# ----------------------------------------------------
# Iter : 16360 / 20000, Time elapsed: 0.33 seconds, Loss: 576257984, EST: 2:10:14
# Iter : 16370 / 20000, Time elapsed: 0.33 seconds, Loss: 510751712, EST: 2:10:46
# Iter : 16380 / 20000, Time elapsed: 0.33 seconds, Loss: 546752768, EST: 2:09:28
# Iter : 16390 / 20000, Time elapsed: 0.33 seconds, Loss: 560945984, EST: 2:09:29
# Iter : 16400 / 20000, Time elapsed: 0.33 seconds, Loss: 577393024, EST: 2:09:54
# ----------------------------------------------------
# Details: iteration 16400, improvement: 1.68 percent, loss: 665702292
# content_loss: 478562400, style_loss_1: 5593784, style_loss_2: 53937485
# style_loss_3: 110519117, style_loss_4: 247631, tv_loss: 16841876
# ----------------------------------------------------
# Iter : 16410 / 20000, Time elapsed: 0.33 seconds, Loss: 605399488, EST: 2:09:21
# Iter : 16420 / 20000, Time elapsed: 0.33 seconds, Loss: 572720640, EST: 2:10:11
# Iter : 16430 / 20000, Time elapsed: 0.33 seconds, Loss: 645737088, EST: 2:09:25
# Iter : 16440 / 20000, Time elapsed: 0.33 seconds, Loss: 587592384, EST: 2:09:29
# Iter : 16450 / 20000, Time elapsed: 0.33 seconds, Loss: 604950080, EST: 2:09:30
# ----------------------------------------------------
# Details: iteration 16450, improvement: -1.39 percent, loss: 674935470
# content_loss: 480796200, style_loss_1: 4065128, style_loss_2: 59302810
# style_loss_3: 114557504, style_loss_4: 255072, tv_loss: 15958756
# ----------------------------------------------------
# Iter : 16460 / 20000, Time elapsed: 0.33 seconds, Loss: 537986304, EST: 2:09:40
# Iter : 16470 / 20000, Time elapsed: 0.33 seconds, Loss: 558776320, EST: 2:09:00
# Iter : 16480 / 20000, Time elapsed: 0.33 seconds, Loss: 667266496, EST: 2:09:13
# Iter : 16490 / 20000, Time elapsed: 0.33 seconds, Loss: 629779968, EST: 2:08:17
# Iter : 16500 / 20000, Time elapsed: 0.33 seconds, Loss: 571710720, EST: 2:08:41
# ----------------------------------------------------
# Details: iteration 16500, improvement: 6.21 percent, loss: 633024053
# content_loss: 461608550, style_loss_1: 5235778, style_loss_2: 59439808
# style_loss_3: 91375328, style_loss_4: 233127, tv_loss: 15131462
# ----------------------------------------------------
# Iter : 16510 / 20000, Time elapsed: 0.33 seconds, Loss: 539400832, EST: 2:08:43
# Iter : 16520 / 20000, Time elapsed: 0.33 seconds, Loss: 555047488, EST: 2:09:45
# Iter : 16530 / 20000, Time elapsed: 0.33 seconds, Loss: 605637120, EST: 2:09:36
# Iter : 16540 / 20000, Time elapsed: 0.33 seconds, Loss: 819749120, EST: 2:08:25
# Iter : 16550 / 20000, Time elapsed: 0.33 seconds, Loss: 533536640, EST: 2:08:57
# ----------------------------------------------------
# Details: iteration 16550, improvement: -6.86 percent, loss: 676453082
# content_loss: 472714900, style_loss_1: 3840976, style_loss_2: 63916467
# style_loss_3: 120187853, style_loss_4: 259467, tv_loss: 15533419
# ----------------------------------------------------
# Iter : 16560 / 20000, Time elapsed: 0.33 seconds, Loss: 557885440, EST: 2:08:05
# Iter : 16570 / 20000, Time elapsed: 0.33 seconds, Loss: 514959008, EST: 2:09:23
# Iter : 16580 / 20000, Time elapsed: 0.33 seconds, Loss: 503262784, EST: 2:10:45
# Iter : 16590 / 20000, Time elapsed: 0.33 seconds, Loss: 651991488, EST: 2:08:17
# Iter : 16600 / 20000, Time elapsed: 0.33 seconds, Loss: 576960064, EST: 2:07:45
# ----------------------------------------------------
# Details: iteration 16600, improvement: 4.42 percent, loss: 646583534
# content_loss: 425253800, style_loss_1: 9878794, style_loss_2: 104242496
# style_loss_3: 92231219, style_loss_4: 236458, tv_loss: 14740767
# ----------------------------------------------------
# Iter : 16610 / 20000, Time elapsed: 0.33 seconds, Loss: 558362368, EST: 2:08:39
# Iter : 16620 / 20000, Time elapsed: 0.33 seconds, Loss: 626969664, EST: 2:08:55
# Iter : 16630 / 20000, Time elapsed: 0.33 seconds, Loss: 698172608, EST: 2:09:05
# Iter : 16640 / 20000, Time elapsed: 0.33 seconds, Loss: 596348864, EST: 2:08:16
# Iter : 16650 / 20000, Time elapsed: 0.33 seconds, Loss: 636904000, EST: 2:08:58
# ----------------------------------------------------
# Details: iteration 16650, improvement: 0.33 percent, loss: 644467741
# content_loss: 439083200, style_loss_1: 12031165, style_loss_2: 83533478
# style_loss_3: 94410893, style_loss_4: 247871, tv_loss: 15161134
# ----------------------------------------------------
# Iter : 16660 / 20000, Time elapsed: 0.33 seconds, Loss: 646830336, EST: 2:09:05
# Iter : 16670 / 20000, Time elapsed: 0.33 seconds, Loss: 558281728, EST: 2:08:12
# Iter : 16680 / 20000, Time elapsed: 0.33 seconds, Loss: 552343360, EST: 2:09:43
# Iter : 16690 / 20000, Time elapsed: 0.33 seconds, Loss: 527257152, EST: 2:09:08
# Iter : 16700 / 20000, Time elapsed: 0.33 seconds, Loss: 595198528, EST: 2:08:33
# ----------------------------------------------------
# Details: iteration 16700, improvement: 3.65 percent, loss: 620916756
# content_loss: 458257950, style_loss_1: 4233878, style_loss_2: 52054131
# style_loss_3: 90276237, style_loss_4: 248314, tv_loss: 15846246
# ----------------------------------------------------
# Iter : 16710 / 20000, Time elapsed: 0.33 seconds, Loss: 611258624, EST: 2:08:02
# Iter : 16720 / 20000, Time elapsed: 0.33 seconds, Loss: 511136960, EST: 2:07:54
# Iter : 16730 / 20000, Time elapsed: 0.33 seconds, Loss: 582677248, EST: 2:08:59
# Iter : 16740 / 20000, Time elapsed: 0.33 seconds, Loss: 585795200, EST: 2:08:54
# Iter : 16750 / 20000, Time elapsed: 0.33 seconds, Loss: 579521536, EST: 2:07:40
# ----------------------------------------------------
# Details: iteration 16750, improvement: 2.30 percent, loss: 606614921
# content_loss: 439848550, style_loss_1: 3346882, style_loss_2: 65289216
# style_loss_3: 81992589, style_loss_4: 255115, tv_loss: 15882570
# ----------------------------------------------------
# Iter : 16760 / 20000, Time elapsed: 0.33 seconds, Loss: 558832640, EST: 2:07:21
# Iter : 16770 / 20000, Time elapsed: 0.33 seconds, Loss: 556998912, EST: 2:07:24
# Iter : 16780 / 20000, Time elapsed: 0.33 seconds, Loss: 579761472, EST: 2:08:20
# Iter : 16790 / 20000, Time elapsed: 0.33 seconds, Loss: 541881856, EST: 2:06:47
# Iter : 16800 / 20000, Time elapsed: 0.33 seconds, Loss: 624584448, EST: 2:07:10
# ----------------------------------------------------
# Details: iteration 16800, improvement: -1.84 percent, loss: 617752935
# content_loss: 464134500, style_loss_1: 2682594, style_loss_2: 41809523
# style_loss_3: 92239661, style_loss_4: 252364, tv_loss: 16634293
# ----------------------------------------------------
# Iter : 16810 / 20000, Time elapsed: 0.33 seconds, Loss: 557221568, EST: 2:07:09
# Iter : 16820 / 20000, Time elapsed: 0.33 seconds, Loss: 509715072, EST: 2:07:46
# Iter : 16830 / 20000, Time elapsed: 0.33 seconds, Loss: 549744576, EST: 2:07:42
# Iter : 16840 / 20000, Time elapsed: 0.33 seconds, Loss: 570899968, EST: 2:06:33
# Iter : 16850 / 20000, Time elapsed: 0.33 seconds, Loss: 582694016, EST: 2:07:07
# ----------------------------------------------------
# Details: iteration 16850, improvement: 1.19 percent, loss: 610415963
# content_loss: 479445600, style_loss_1: 2245466, style_loss_2: 34086656
# style_loss_3: 77752755, style_loss_4: 263074, tv_loss: 16622412
# ----------------------------------------------------
# Iter : 16860 / 20000, Time elapsed: 0.33 seconds, Loss: 569652672, EST: 2:07:00
# Iter : 16870 / 20000, Time elapsed: 0.33 seconds, Loss: 606731904, EST: 2:07:19
# Iter : 16880 / 20000, Time elapsed: 0.33 seconds, Loss: 526090496, EST: 2:06:59
# Iter : 16890 / 20000, Time elapsed: 0.33 seconds, Loss: 592941568, EST: 2:06:44
# Iter : 16900 / 20000, Time elapsed: 0.33 seconds, Loss: 534310432, EST: 2:07:14
# ----------------------------------------------------
# Details: iteration 16900, improvement: 0.16 percent, loss: 609456795
# content_loss: 437561200, style_loss_1: 4578342, style_loss_2: 65952013
# style_loss_3: 85662445, style_loss_4: 244889, tv_loss: 15457906
# ----------------------------------------------------
# Iter : 16910 / 20000, Time elapsed: 0.33 seconds, Loss: 622048576, EST: 2:06:04
# Iter : 16920 / 20000, Time elapsed: 0.33 seconds, Loss: 564189376, EST: 2:07:04
# Iter : 16930 / 20000, Time elapsed: 0.33 seconds, Loss: 554603520, EST: 2:06:32
# Iter : 16940 / 20000, Time elapsed: 0.33 seconds, Loss: 640628864, EST: 2:08:23
# Iter : 16950 / 20000, Time elapsed: 0.33 seconds, Loss: 662509440, EST: 2:06:38
# ----------------------------------------------------
# Details: iteration 16950, improvement: 1.61 percent, loss: 599640009
# content_loss: 450915700, style_loss_1: 4414724, style_loss_2: 47317773
# style_loss_3: 80528506, style_loss_4: 255610, tv_loss: 16207696
# ----------------------------------------------------
# Iter : 16960 / 20000, Time elapsed: 0.33 seconds, Loss: 602646272, EST: 2:06:43
# Iter : 16970 / 20000, Time elapsed: 0.33 seconds, Loss: 584217984, EST: 2:06:12
# Iter : 16980 / 20000, Time elapsed: 0.33 seconds, Loss: 631057600, EST: 2:06:40
# Iter : 16990 / 20000, Time elapsed: 0.33 seconds, Loss: 581739520, EST: 2:05:47
# Iter : 17000 / 20000, Time elapsed: 0.33 seconds, Loss: 579367424, EST: 2:06:08
# ----------------------------------------------------
# Details: iteration 17000, improvement: -1.59 percent, loss: 609201725
# content_loss: 447032150, style_loss_1: 5059407, style_loss_2: 53826342
# style_loss_3: 86164832, style_loss_4: 252215, tv_loss: 16866778
# ----------------------------------------------------
# Iter : 17010 / 20000, Time elapsed: 0.33 seconds, Loss: 565842048, EST: 2:07:00
# Iter : 17020 / 20000, Time elapsed: 0.33 seconds, Loss: 588426112, EST: 2:06:08
# Iter : 17030 / 20000, Time elapsed: 0.33 seconds, Loss: 563502144, EST: 2:06:43
# Iter : 17040 / 20000, Time elapsed: 0.33 seconds, Loss: 547041664, EST: 2:05:41
# Iter : 17050 / 20000, Time elapsed: 0.33 seconds, Loss: 582708800, EST: 2:06:17
# ----------------------------------------------------
# Details: iteration 17050, improvement: -4.79 percent, loss: 638385674
# content_loss: 425331500, style_loss_1: 6142752, style_loss_2: 98483699
# style_loss_3: 93077274, style_loss_4: 247612, tv_loss: 15102837
# ----------------------------------------------------
# Iter : 17060 / 20000, Time elapsed: 0.33 seconds, Loss: 573099520, EST: 2:05:57
# Iter : 17070 / 20000, Time elapsed: 0.33 seconds, Loss: 578935424, EST: 2:06:54
# Iter : 17080 / 20000, Time elapsed: 0.33 seconds, Loss: 544531584, EST: 2:05:19
# Iter : 17090 / 20000, Time elapsed: 0.33 seconds, Loss: 568064768, EST: 2:06:05
# Iter : 17100 / 20000, Time elapsed: 0.33 seconds, Loss: 595232128, EST: 2:05:52
# ----------------------------------------------------
# Details: iteration 17100, improvement: 0.83 percent, loss: 633063440
# content_loss: 470831450, style_loss_1: 3545344, style_loss_2: 45393530
# style_loss_3: 95744851, style_loss_4: 253742, tv_loss: 17294522
# ----------------------------------------------------
# Iter : 17110 / 20000, Time elapsed: 0.33 seconds, Loss: 553334912, EST: 2:06:42
# Iter : 17120 / 20000, Time elapsed: 0.33 seconds, Loss: 556299776, EST: 2:05:43
# Iter : 17130 / 20000, Time elapsed: 0.33 seconds, Loss: 559994240, EST: 2:05:09
# Iter : 17140 / 20000, Time elapsed: 0.33 seconds, Loss: 565986240, EST: 2:05:02
# Iter : 17150 / 20000, Time elapsed: 0.33 seconds, Loss: 573319616, EST: 2:06:12
# ----------------------------------------------------
# Details: iteration 17150, improvement: 5.12 percent, loss: 600660977
# content_loss: 460141050, style_loss_1: 2980826, style_loss_2: 42534602
# style_loss_3: 77634259, style_loss_4: 248470, tv_loss: 17121770
# ----------------------------------------------------
# Iter : 17160 / 20000, Time elapsed: 0.33 seconds, Loss: 651725632, EST: 2:05:12
# Iter : 17170 / 20000, Time elapsed: 0.33 seconds, Loss: 552266112, EST: 2:05:36
# Iter : 17180 / 20000, Time elapsed: 0.33 seconds, Loss: 566376704, EST: 2:05:24
# Iter : 17190 / 20000, Time elapsed: 0.33 seconds, Loss: 701135680, EST: 2:04:58
# Iter : 17200 / 20000, Time elapsed: 0.33 seconds, Loss: 588015744, EST: 2:04:17
# ----------------------------------------------------
# Details: iteration 17200, improvement: -2.52 percent, loss: 615769816
# content_loss: 452991150, style_loss_1: 3431090, style_loss_2: 62903386
# style_loss_3: 80425126, style_loss_4: 228915, tv_loss: 15790150
# ----------------------------------------------------
# Iter : 17210 / 20000, Time elapsed: 0.33 seconds, Loss: 578909824, EST: 2:05:01
# Iter : 17220 / 20000, Time elapsed: 0.33 seconds, Loss: 641493056, EST: 2:05:16
# Iter : 17230 / 20000, Time elapsed: 0.33 seconds, Loss: 539144320, EST: 2:05:58
# Iter : 17240 / 20000, Time elapsed: 0.33 seconds, Loss: 563838336, EST: 2:04:44
# Iter : 17250 / 20000, Time elapsed: 0.33 seconds, Loss: 660193920, EST: 2:04:37
# ----------------------------------------------------
# Details: iteration 17250, improvement: -11.81 percent, loss: 688488045
# content_loss: 422579950, style_loss_1: 12502355, style_loss_2: 118152346
# style_loss_3: 114693939, style_loss_4: 260709, tv_loss: 20298746
# ----------------------------------------------------
# Iter : 17260 / 20000, Time elapsed: 0.33 seconds, Loss: 577500864, EST: 2:05:16
# Iter : 17270 / 20000, Time elapsed: 0.33 seconds, Loss: 579947072, EST: 2:05:37
# Iter : 17280 / 20000, Time elapsed: 0.33 seconds, Loss: 574601536, EST: 2:04:22
# Iter : 17290 / 20000, Time elapsed: 0.33 seconds, Loss: 540275072, EST: 2:04:19
# Iter : 17300 / 20000, Time elapsed: 0.33 seconds, Loss: 641612800, EST: 2:04:14
# ----------------------------------------------------
# Details: iteration 17300, improvement: 9.14 percent, loss: 625566555
# content_loss: 442601500, style_loss_1: 5630742, style_loss_2: 67747507
# style_loss_3: 91248294, style_loss_4: 262475, tv_loss: 18076036
# ----------------------------------------------------
# Iter : 17310 / 20000, Time elapsed: 0.33 seconds, Loss: 604184832, EST: 2:05:17
# Iter : 17320 / 20000, Time elapsed: 0.33 seconds, Loss: 509191200, EST: 2:05:01
# Iter : 17330 / 20000, Time elapsed: 0.33 seconds, Loss: 611591680, EST: 2:05:13
# Iter : 17340 / 20000, Time elapsed: 0.33 seconds, Loss: 599391936, EST: 2:04:57
# Iter : 17350 / 20000, Time elapsed: 0.33 seconds, Loss: 584915776, EST: 2:04:45
# ----------------------------------------------------
# Details: iteration 17350, improvement: 1.26 percent, loss: 617684670
# content_loss: 466995350, style_loss_1: 3118469, style_loss_2: 44051648
# style_loss_3: 86295283, style_loss_4: 253932, tv_loss: 16969988
# ----------------------------------------------------
# Iter : 17360 / 20000, Time elapsed: 0.33 seconds, Loss: 595613696, EST: 2:05:11
# Iter : 17370 / 20000, Time elapsed: 0.33 seconds, Loss: 555733184, EST: 2:04:25
# Iter : 17380 / 20000, Time elapsed: 0.33 seconds, Loss: 527532864, EST: 2:04:20
# Iter : 17390 / 20000, Time elapsed: 0.33 seconds, Loss: 504614400, EST: 2:04:43
# Iter : 17400 / 20000, Time elapsed: 0.33 seconds, Loss: 567111744, EST: 2:03:41
# ----------------------------------------------------
# Details: iteration 17400, improvement: 1.18 percent, loss: 610375716
# content_loss: 468504500, style_loss_1: 3934007, style_loss_2: 42004371
# style_loss_3: 78675174, style_loss_4: 241593, tv_loss: 17016070
# ----------------------------------------------------
# Iter : 17410 / 20000, Time elapsed: 0.33 seconds, Loss: 538341248, EST: 2:03:44
# Iter : 17420 / 20000, Time elapsed: 0.33 seconds, Loss: 544827840, EST: 2:04:43
# Iter : 17430 / 20000, Time elapsed: 0.33 seconds, Loss: 624360768, EST: 2:05:03
# Iter : 17440 / 20000, Time elapsed: 0.33 seconds, Loss: 631959168, EST: 2:03:58
# Iter : 17450 / 20000, Time elapsed: 0.33 seconds, Loss: 673767232, EST: 2:02:51
# ----------------------------------------------------
# Details: iteration 17450, improvement: 1.14 percent, loss: 603391722
# content_loss: 441677750, style_loss_1: 5796794, style_loss_2: 61761075
# style_loss_3: 77085126, style_loss_4: 259287, tv_loss: 16811690
# ----------------------------------------------------
# Iter : 17460 / 20000, Time elapsed: 0.33 seconds, Loss: 602415168, EST: 2:03:55
# Iter : 17470 / 20000, Time elapsed: 0.33 seconds, Loss: 577099520, EST: 2:02:57
# Iter : 17480 / 20000, Time elapsed: 0.33 seconds, Loss: 583804608, EST: 2:04:11
# Iter : 17490 / 20000, Time elapsed: 0.33 seconds, Loss: 531145728, EST: 2:03:04
# Iter : 17500 / 20000, Time elapsed: 0.33 seconds, Loss: 607913728, EST: 2:03:12
# ----------------------------------------------------
# Details: iteration 17500, improvement: 3.70 percent, loss: 581095344
# content_loss: 457541850, style_loss_1: 3414658, style_loss_2: 32641933
# style_loss_3: 70595763, style_loss_4: 258811, tv_loss: 16642330
# ----------------------------------------------------
# Iter : 17510 / 20000, Time elapsed: 0.33 seconds, Loss: 601588352, EST: 2:03:36
# Iter : 17520 / 20000, Time elapsed: 0.33 seconds, Loss: 532831584, EST: 2:02:54
# Iter : 17530 / 20000, Time elapsed: 0.33 seconds, Loss: 562917312, EST: 2:02:45
# Iter : 17540 / 20000, Time elapsed: 0.33 seconds, Loss: 588903808, EST: 2:02:55
# Iter : 17550 / 20000, Time elapsed: 0.33 seconds, Loss: 601610560, EST: 2:04:08
# ----------------------------------------------------
# Details: iteration 17550, improvement: -8.91 percent, loss: 632846915
# content_loss: 462692350, style_loss_1: 7437040, style_loss_2: 53591731
# style_loss_3: 92026880, style_loss_4: 277359, tv_loss: 16821554
# ----------------------------------------------------
# Iter : 17560 / 20000, Time elapsed: 0.33 seconds, Loss: 517329920, EST: 2:03:14
# Iter : 17570 / 20000, Time elapsed: 0.33 seconds, Loss: 573868800, EST: 2:03:05
# Iter : 17580 / 20000, Time elapsed: 0.33 seconds, Loss: 602413888, EST: 2:03:37
# Iter : 17590 / 20000, Time elapsed: 0.33 seconds, Loss: 594023296, EST: 2:04:28
# Iter : 17600 / 20000, Time elapsed: 0.33 seconds, Loss: 608762304, EST: 2:03:00
# ----------------------------------------------------
# Details: iteration 17600, improvement: 3.57 percent, loss: 610245744
# content_loss: 462337450, style_loss_1: 3696261, style_loss_2: 50742138
# style_loss_3: 76208218, style_loss_4: 245286, tv_loss: 17016392
# ----------------------------------------------------
# Iter : 17610 / 20000, Time elapsed: 0.33 seconds, Loss: 614529408, EST: 2:03:30
# Iter : 17620 / 20000, Time elapsed: 0.33 seconds, Loss: 526258880, EST: 2:02:44
# Iter : 17630 / 20000, Time elapsed: 0.33 seconds, Loss: 598002560, EST: 2:03:15
# Iter : 17640 / 20000, Time elapsed: 0.33 seconds, Loss: 553409728, EST: 2:03:13
# Iter : 17650 / 20000, Time elapsed: 0.33 seconds, Loss: 474619840, EST: 2:02:10
# ----------------------------------------------------
# Details: iteration 17650, improvement: -0.96 percent, loss: 616073902
# content_loss: 460972100, style_loss_1: 3768989, style_loss_2: 44239584
# style_loss_3: 90832000, style_loss_4: 266549, tv_loss: 15994681
# ----------------------------------------------------
# Iter : 17660 / 20000, Time elapsed: 0.33 seconds, Loss: 583750016, EST: 2:02:31
# Iter : 17670 / 20000, Time elapsed: 0.33 seconds, Loss: 568625728, EST: 2:02:27
# Iter : 17680 / 20000, Time elapsed: 0.33 seconds, Loss: 593102336, EST: 2:02:32
# Iter : 17690 / 20000, Time elapsed: 0.33 seconds, Loss: 558923264, EST: 2:02:54
# Iter : 17700 / 20000, Time elapsed: 0.33 seconds, Loss: 540793152, EST: 2:01:27
# ----------------------------------------------------
# Details: iteration 17700, improvement: -5.22 percent, loss: 648219603
# content_loss: 469409200, style_loss_1: 4537004, style_loss_2: 50327821
# style_loss_3: 107343277, style_loss_4: 274492, tv_loss: 16327810
# ----------------------------------------------------
# Iter : 17710 / 20000, Time elapsed: 0.33 seconds, Loss: 668120000, EST: 2:02:22
# Iter : 17720 / 20000, Time elapsed: 0.33 seconds, Loss: 677786048, EST: 2:02:36
# Iter : 17730 / 20000, Time elapsed: 0.33 seconds, Loss: 619431552, EST: 2:01:43
# Iter : 17740 / 20000, Time elapsed: 0.33 seconds, Loss: 552308288, EST: 2:01:19
# Iter : 17750 / 20000, Time elapsed: 0.33 seconds, Loss: 566064640, EST: 2:02:51
# ----------------------------------------------------
# Details: iteration 17750, improvement: 3.76 percent, loss: 623843063
# content_loss: 433169100, style_loss_1: 3826470, style_loss_2: 74917363
# style_loss_3: 96232614, style_loss_4: 266062, tv_loss: 15431454
# ----------------------------------------------------
# Iter : 17760 / 20000, Time elapsed: 0.33 seconds, Loss: 627880704, EST: 2:03:51
# Iter : 17770 / 20000, Time elapsed: 0.33 seconds, Loss: 543480896, EST: 2:02:58
# Iter : 17780 / 20000, Time elapsed: 0.33 seconds, Loss: 660558208, EST: 2:02:11
# Iter : 17790 / 20000, Time elapsed: 0.33 seconds, Loss: 599017024, EST: 2:02:03
# Iter : 17800 / 20000, Time elapsed: 0.33 seconds, Loss: 600595904, EST: 2:01:48
# ----------------------------------------------------
# Details: iteration 17800, improvement: -1.48 percent, loss: 633104844
# content_loss: 463674000, style_loss_1: 3216486, style_loss_2: 52551427
# style_loss_3: 96550438, style_loss_4: 248402, tv_loss: 16864090
# ----------------------------------------------------
# Iter : 17810 / 20000, Time elapsed: 0.33 seconds, Loss: 590823232, EST: 2:02:08
# Iter : 17820 / 20000, Time elapsed: 0.33 seconds, Loss: 529493888, EST: 2:01:36
# Iter : 17830 / 20000, Time elapsed: 0.33 seconds, Loss: 585243456, EST: 2:01:05
# Iter : 17840 / 20000, Time elapsed: 0.33 seconds, Loss: 583594560, EST: 2:00:56
# Iter : 17850 / 20000, Time elapsed: 0.33 seconds, Loss: 626297408, EST: 2:01:52
# ----------------------------------------------------
# Details: iteration 17850, improvement: 1.83 percent, loss: 621538934
# content_loss: 427742900, style_loss_1: 4814164, style_loss_2: 81305920
# style_loss_3: 91046899, style_loss_4: 252785, tv_loss: 16376266
# ----------------------------------------------------
# Iter : 17860 / 20000, Time elapsed: 0.33 seconds, Loss: 614066944, EST: 2:01:42
# Iter : 17870 / 20000, Time elapsed: 0.33 seconds, Loss: 627668032, EST: 2:01:56
# Iter : 17880 / 20000, Time elapsed: 0.33 seconds, Loss: 576864704, EST: 2:02:24
# Iter : 17890 / 20000, Time elapsed: 0.33 seconds, Loss: 619591488, EST: 2:00:43
# Iter : 17900 / 20000, Time elapsed: 0.33 seconds, Loss: 572596992, EST: 2:01:50
# ----------------------------------------------------
# Details: iteration 17900, improvement: -2.72 percent, loss: 638456522
# content_loss: 437634650, style_loss_1: 5221587, style_loss_2: 81058010
# style_loss_3: 97816525, style_loss_4: 269957, tv_loss: 16455794
# ----------------------------------------------------
# Iter : 17910 / 20000, Time elapsed: 0.33 seconds, Loss: 579018560, EST: 2:01:42
# Iter : 17920 / 20000, Time elapsed: 0.33 seconds, Loss: 546672320, EST: 2:01:38
# Iter : 17930 / 20000, Time elapsed: 0.33 seconds, Loss: 589885696, EST: 2:02:04
# Iter : 17940 / 20000, Time elapsed: 0.33 seconds, Loss: 571654528, EST: 2:00:47
# Iter : 17950 / 20000, Time elapsed: 0.33 seconds, Loss: 542832128, EST: 2:00:50
# ----------------------------------------------------
# Details: iteration 17950, improvement: 2.34 percent, loss: 623542441
# content_loss: 424583100, style_loss_1: 12107550, style_loss_2: 80848627
# style_loss_3: 89072858, style_loss_4: 242162, tv_loss: 16688144
# ----------------------------------------------------
# Iter : 17960 / 20000, Time elapsed: 0.33 seconds, Loss: 606971264, EST: 2:01:13
# Iter : 17970 / 20000, Time elapsed: 0.33 seconds, Loss: 543600960, EST: 2:00:32
# Iter : 17980 / 20000, Time elapsed: 0.33 seconds, Loss: 602021376, EST: 2:00:21
# Iter : 17990 / 20000, Time elapsed: 0.33 seconds, Loss: 520933280, EST: 2:00:45
# Iter : 18000 / 20000, Time elapsed: 0.33 seconds, Loss: 538428608, EST: 1:59:47
# ----------------------------------------------------
# Details: iteration 18000, improvement: -1.42 percent, loss: 632414166
# content_loss: 434523200, style_loss_1: 10281642, style_loss_2: 70366131
# style_loss_3: 100169235, style_loss_4: 277266, tv_loss: 16796692
# ----------------------------------------------------
# Iter : 18010 / 20000, Time elapsed: 0.33 seconds, Loss: 510201408, EST: 2:01:26
# Iter : 18020 / 20000, Time elapsed: 0.33 seconds, Loss: 527229024, EST: 2:00:54
# Iter : 18030 / 20000, Time elapsed: 0.33 seconds, Loss: 531675840, EST: 2:00:21
# Iter : 18040 / 20000, Time elapsed: 0.33 seconds, Loss: 553279104, EST: 2:01:41
# Iter : 18050 / 20000, Time elapsed: 0.33 seconds, Loss: 641778048, EST: 1:59:58
# ----------------------------------------------------
# Details: iteration 18050, improvement: 6.50 percent, loss: 591295507
# content_loss: 445591650, style_loss_1: 2904405, style_loss_2: 46895290
# style_loss_3: 79715110, style_loss_4: 270924, tv_loss: 15918128
# ----------------------------------------------------
# Iter : 18060 / 20000, Time elapsed: 0.33 seconds, Loss: 565544448, EST: 2:01:56
# Iter : 18070 / 20000, Time elapsed: 0.33 seconds, Loss: 503055968, EST: 2:01:19
# Iter : 18080 / 20000, Time elapsed: 0.33 seconds, Loss: 636001856, EST: 2:00:35
# Iter : 18090 / 20000, Time elapsed: 0.33 seconds, Loss: 603211136, EST: 2:00:11
# Iter : 18100 / 20000, Time elapsed: 0.33 seconds, Loss: 534375072, EST: 1:59:38
# ----------------------------------------------------
# Details: iteration 18100, improvement: -2.05 percent, loss: 603406435
# content_loss: 439748500, style_loss_1: 4548504, style_loss_2: 58065318
# style_loss_3: 84650976, style_loss_4: 258220, tv_loss: 16134916
# ----------------------------------------------------
# Iter : 18110 / 20000, Time elapsed: 0.33 seconds, Loss: 534191776, EST: 1:59:50
# Iter : 18120 / 20000, Time elapsed: 0.33 seconds, Loss: 567501888, EST: 2:00:05
# Iter : 18130 / 20000, Time elapsed: 0.33 seconds, Loss: 614671872, EST: 1:59:38
# Iter : 18140 / 20000, Time elapsed: 0.33 seconds, Loss: 546531712, EST: 1:59:55
# Iter : 18150 / 20000, Time elapsed: 0.33 seconds, Loss: 632373312, EST: 1:59:40
# ----------------------------------------------------
# Details: iteration 18150, improvement: -4.24 percent, loss: 628969556
# content_loss: 474735650, style_loss_1: 4597315, style_loss_2: 47317526
# style_loss_3: 85419290, style_loss_4: 236377, tv_loss: 16663398
# ----------------------------------------------------
# Iter : 18160 / 20000, Time elapsed: 0.33 seconds, Loss: 609896896, EST: 1:59:43
# Iter : 18170 / 20000, Time elapsed: 0.33 seconds, Loss: 579621888, EST: 1:59:30
# Iter : 18180 / 20000, Time elapsed: 0.33 seconds, Loss: 578069312, EST: 2:00:22
# Iter : 18190 / 20000, Time elapsed: 0.33 seconds, Loss: 656056768, EST: 1:59:58
# Iter : 18200 / 20000, Time elapsed: 0.33 seconds, Loss: 499778560, EST: 1:59:21
# ----------------------------------------------------
# Details: iteration 18200, improvement: -0.30 percent, loss: 630868532
# content_loss: 468570100, style_loss_1: 2429972, style_loss_2: 43500691
# style_loss_3: 96521766, style_loss_4: 280431, tv_loss: 19565572
# ----------------------------------------------------
# Iter : 18210 / 20000, Time elapsed: 0.33 seconds, Loss: 560911488, EST: 2:00:11
# Iter : 18220 / 20000, Time elapsed: 0.33 seconds, Loss: 471234528, EST: 1:59:26
# Iter : 18230 / 20000, Time elapsed: 0.33 seconds, Loss: 468907328, EST: 1:59:08
# Iter : 18240 / 20000, Time elapsed: 0.33 seconds, Loss: 560901248, EST: 2:00:20
# Iter : 18250 / 20000, Time elapsed: 0.33 seconds, Loss: 596089024, EST: 1:59:30
# ----------------------------------------------------
# Details: iteration 18250, improvement: 3.21 percent, loss: 610621057
# content_loss: 441948200, style_loss_1: 4067034, style_loss_2: 61892749
# style_loss_3: 86690208, style_loss_4: 235178, tv_loss: 15787688
# ----------------------------------------------------
# Iter : 18260 / 20000, Time elapsed: 0.33 seconds, Loss: 694127232, EST: 1:58:45
# Iter : 18270 / 20000, Time elapsed: 0.33 seconds, Loss: 607873216, EST: 2:00:07
# Iter : 18280 / 20000, Time elapsed: 0.33 seconds, Loss: 576992448, EST: 1:59:46
# Iter : 18290 / 20000, Time elapsed: 0.33 seconds, Loss: 537172672, EST: 1:59:15
# Iter : 18300 / 20000, Time elapsed: 0.33 seconds, Loss: 556505088, EST: 1:58:43
# ----------------------------------------------------
# Details: iteration 18300, improvement: -0.97 percent, loss: 616554449
# content_loss: 455435750, style_loss_1: 8392398, style_loss_2: 55355904
# style_loss_3: 81505242, style_loss_4: 260433, tv_loss: 15604722
# ----------------------------------------------------
# Iter : 18310 / 20000, Time elapsed: 0.33 seconds, Loss: 523646816, EST: 1:59:39
# Iter : 18320 / 20000, Time elapsed: 0.33 seconds, Loss: 531560096, EST: 1:58:39
# Iter : 18330 / 20000, Time elapsed: 0.33 seconds, Loss: 630282240, EST: 1:58:51
# Iter : 18340 / 20000, Time elapsed: 0.33 seconds, Loss: 623201344, EST: 1:58:22
# Iter : 18350 / 20000, Time elapsed: 0.33 seconds, Loss: 566917440, EST: 1:58:45
# ----------------------------------------------------
# Details: iteration 18350, improvement: 0.30 percent, loss: 614697966
# content_loss: 461563650, style_loss_1: 4537291, style_loss_2: 42460570
# style_loss_3: 87683155, style_loss_4: 230436, tv_loss: 18222864
# ----------------------------------------------------
# Iter : 18360 / 20000, Time elapsed: 0.33 seconds, Loss: 525740128, EST: 1:58:42
# Iter : 18370 / 20000, Time elapsed: 0.33 seconds, Loss: 535090848, EST: 1:58:55
# Iter : 18380 / 20000, Time elapsed: 0.33 seconds, Loss: 521439424, EST: 1:58:08
# Iter : 18390 / 20000, Time elapsed: 0.33 seconds, Loss: 558219520, EST: 1:58:38
# Iter : 18400 / 20000, Time elapsed: 0.33 seconds, Loss: 572879808, EST: 1:58:30
# ----------------------------------------------------
# Details: iteration 18400, improvement: -1.10 percent, loss: 621437933
# content_loss: 445370550, style_loss_1: 3617204, style_loss_2: 59265754
# style_loss_3: 94686944, style_loss_4: 280665, tv_loss: 18216816
# ----------------------------------------------------
# ...
# Iter : 18950 / 20000, Time elapsed: 0.33 seconds, Loss: 521825888, EST: 0:05:48
# ----------------------------------------------------
# Details: iteration 18950, improvement: 7.86 percent, loss: 557284844
# content_loss: 421805750, style_loss_1: 3931416, style_loss_2: 39295251
# style_loss_3: 75926029, style_loss_4: 262128, tv_loss: 16064270
# ----------------------------------------------------
# Iter : 18960 / 20000, Time elapsed: 0.33 seconds, Loss: 505120192, EST: 0:05:43
# Iter : 18970 / 20000, Time elapsed: 0.33 seconds, Loss: 516857568, EST: 0:05:40
# Iter : 18980 / 20000, Time elapsed: 0.33 seconds, Loss: 590746368, EST: 0:05:38
# Iter : 18990 / 20000, Time elapsed: 0.33 seconds, Loss: 491578432, EST: 0:05:35
# Iter : 19000 / 20000, Time elapsed: 0.33 seconds, Loss: 480642560, EST: 0:05:30
# ----------------------------------------------------
# Details: iteration 19000, improvement: -4.50 percent, loss: 582355483
# content_loss: 424033800, style_loss_1: 3807381, style_loss_2: 46328774
# style_loss_3: 91872102, style_loss_4: 276258, tv_loss: 16037168
# ----------------------------------------------------
# Iter : 19010 / 20000, Time elapsed: 0.33 seconds, Loss: 561542848, EST: 0:05:26
# Iter : 19020 / 20000, Time elapsed: 0.33 seconds, Loss: 541858304, EST: 0:05:24
# Iter : 19030 / 20000, Time elapsed: 0.33 seconds, Loss: 550185984, EST: 0:05:21
# Iter : 19040 / 20000, Time elapsed: 0.33 seconds, Loss: 527843648, EST: 0:05:19
# Iter : 19050 / 20000, Time elapsed: 0.33 seconds, Loss: 514528864, EST: 0:05:15
# ----------------------------------------------------
# Details: iteration 19050, improvement: 3.74 percent, loss: 560572615
# content_loss: 418807325, style_loss_1: 2341396, style_loss_2: 46319411
# style_loss_3: 77038144, style_loss_4: 271549, tv_loss: 15794790
# ----------------------------------------------------
# Iter : 19060 / 20000, Time elapsed: 0.33 seconds, Loss: 538780608, EST: 0:05:13
# Iter : 19070 / 20000, Time elapsed: 0.33 seconds, Loss: 496170784, EST: 0:05:07
# Iter : 19080 / 20000, Time elapsed: 0.33 seconds, Loss: 496465856, EST: 0:05:05
# Iter : 19090 / 20000, Time elapsed: 0.33 seconds, Loss: 668555712, EST: 0:05:03
# Iter : 19100 / 20000, Time elapsed: 0.33 seconds, Loss: 495763872, EST: 0:05:00
# ----------------------------------------------------
# Details: iteration 19100, improvement: -0.61 percent, loss: 564008951
# content_loss: 436488200, style_loss_1: 2845105, style_loss_2: 39735328
# style_loss_3: 68398579, style_loss_4: 259253, tv_loss: 16282486
# ----------------------------------------------------
# Iter : 19110 / 20000, Time elapsed: 0.33 seconds, Loss: 579798656, EST: 0:04:56
# Iter : 19120 / 20000, Time elapsed: 0.33 seconds, Loss: 502520096, EST: 0:04:51
# Iter : 19130 / 20000, Time elapsed: 0.33 seconds, Loss: 513845216, EST: 0:04:46
# Iter : 19140 / 20000, Time elapsed: 0.33 seconds, Loss: 553550016, EST: 0:04:43
# Iter : 19150 / 20000, Time elapsed: 0.33 seconds, Loss: 508909184, EST: 0:04:43
# ----------------------------------------------------
# Details: iteration 19150, improvement: -1.75 percent, loss: 573898598
# content_loss: 406135475, style_loss_1: 6971216, style_loss_2: 65855872
# style_loss_3: 79388544, style_loss_4: 270665, tv_loss: 15276826
# ----------------------------------------------------
# Iter : 19160 / 20000, Time elapsed: 0.33 seconds, Loss: 562321856, EST: 0:04:38
# Iter : 19170 / 20000, Time elapsed: 0.33 seconds, Loss: 493465312, EST: 0:04:37
# Iter : 19180 / 20000, Time elapsed: 0.33 seconds, Loss: 452388672, EST: 0:04:32
# Iter : 19190 / 20000, Time elapsed: 0.33 seconds, Loss: 550187520, EST: 0:04:28
# Iter : 19200 / 20000, Time elapsed: 0.33 seconds, Loss: 484453120, EST: 0:04:25
# ----------------------------------------------------
# Details: iteration 19200, improvement: 3.83 percent, loss: 551926003
# content_loss: 417164425, style_loss_1: 3375297, style_loss_2: 47154237
# style_loss_3: 68547808, style_loss_4: 259706, tv_loss: 15424530
# ----------------------------------------------------
# Iter : 19210 / 20000, Time elapsed: 0.33 seconds, Loss: 592499520, EST: 0:04:21
# Iter : 19220 / 20000, Time elapsed: 0.33 seconds, Loss: 573763648, EST: 0:04:19
# Iter : 19230 / 20000, Time elapsed: 0.33 seconds, Loss: 580808576, EST: 0:04:13
# Iter : 19240 / 20000, Time elapsed: 0.33 seconds, Loss: 546184640, EST: 0:04:11
# Iter : 19250 / 20000, Time elapsed: 0.33 seconds, Loss: 482009280, EST: 0:04:08
# ----------------------------------------------------
# Details: iteration 19250, improvement: -1.30 percent, loss: 559087040
# content_loss: 425951000, style_loss_1: 3363601, style_loss_2: 42565958
# style_loss_3: 71531379, style_loss_4: 266892, tv_loss: 15408209
# ----------------------------------------------------
# Iter : 19260 / 20000, Time elapsed: 0.33 seconds, Loss: 472662464, EST: 0:04:06
# Iter : 19270 / 20000, Time elapsed: 0.33 seconds, Loss: 573627072, EST: 0:04:02
# Iter : 19280 / 20000, Time elapsed: 0.33 seconds, Loss: 517553248, EST: 0:03:56
# Iter : 19290 / 20000, Time elapsed: 0.33 seconds, Loss: 531208896, EST: 0:03:55
# Iter : 19300 / 20000, Time elapsed: 0.33 seconds, Loss: 554013632, EST: 0:03:51
# ----------------------------------------------------
# Details: iteration 19300, improvement: 0.21 percent, loss: 557922437
# content_loss: 428343300, style_loss_1: 2670027, style_loss_2: 38411706
# style_loss_3: 72104704, style_loss_4: 273158, tv_loss: 16119542
# ----------------------------------------------------
# Iter : 19310 / 20000, Time elapsed: 0.33 seconds, Loss: 515771488, EST: 0:03:50
# Iter : 19320 / 20000, Time elapsed: 0.33 seconds, Loss: 540281664, EST: 0:03:46
# Iter : 19330 / 20000, Time elapsed: 0.33 seconds, Loss: 729907584, EST: 0:03:42
# Iter : 19340 / 20000, Time elapsed: 0.33 seconds, Loss: 628417472, EST: 0:03:38
# Iter : 19350 / 20000, Time elapsed: 0.33 seconds, Loss: 533614400, EST: 0:03:35
# ----------------------------------------------------
# Details: iteration 19350, improvement: -1.31 percent, loss: 565209995
# content_loss: 410234350, style_loss_1: 4581861, style_loss_2: 60615949
# style_loss_3: 73603456, style_loss_4: 277406, tv_loss: 15896974
# ----------------------------------------------------
# Iter : 19360 / 20000, Time elapsed: 0.33 seconds, Loss: 587327552, EST: 0:03:31
# Iter : 19370 / 20000, Time elapsed: 0.33 seconds, Loss: 620166272, EST: 0:03:29
# Iter : 19380 / 20000, Time elapsed: 0.33 seconds, Loss: 522981024, EST: 0:03:25
# Iter : 19390 / 20000, Time elapsed: 0.33 seconds, Loss: 573369024, EST: 0:03:24
# Iter : 19400 / 20000, Time elapsed: 0.33 seconds, Loss: 496303744, EST: 0:03:19
# ----------------------------------------------------
# Details: iteration 19400, improvement: -3.15 percent, loss: 583018919
# content_loss: 433346450, style_loss_1: 2864837, style_loss_2: 45701114
# style_loss_3: 84477120, style_loss_4: 275451, tv_loss: 16353948
# ----------------------------------------------------
# Iter : 19410 / 20000, Time elapsed: 0.33 seconds, Loss: 471024864, EST: 0:03:15
# Iter : 19420 / 20000, Time elapsed: 0.33 seconds, Loss: 473159488, EST: 0:03:12
# Iter : 19430 / 20000, Time elapsed: 0.33 seconds, Loss: 483929824, EST: 0:03:10
# Iter : 19440 / 20000, Time elapsed: 0.33 seconds, Loss: 561939904, EST: 0:03:05
# Iter : 19450 / 20000, Time elapsed: 0.33 seconds, Loss: 545046784, EST: 0:03:01
# ----------------------------------------------------
# Details: iteration 19450, improvement: -0.11 percent, loss: 583653708
# content_loss: 407693025, style_loss_1: 6436125, style_loss_2: 70787130
# style_loss_3: 82584358, style_loss_4: 293350, tv_loss: 15859721
# ----------------------------------------------------
# Iter : 19460 / 20000, Time elapsed: 0.33 seconds, Loss: 589668352, EST: 0:02:58
# Iter : 19470 / 20000, Time elapsed: 0.33 seconds, Loss: 518139232, EST: 0:02:55
# Iter : 19480 / 20000, Time elapsed: 0.33 seconds, Loss: 597848896, EST: 0:02:51
# Iter : 19490 / 20000, Time elapsed: 0.33 seconds, Loss: 539258880, EST: 0:02:48
# Iter : 19500 / 20000, Time elapsed: 0.33 seconds, Loss: 525637856, EST: 0:02:46
# ----------------------------------------------------
# Details: iteration 19500, improvement: 2.25 percent, loss: 570526632
# content_loss: 417337900, style_loss_1: 3405912, style_loss_2: 47880173
# style_loss_3: 85801741, style_loss_4: 289002, tv_loss: 15811905
# ----------------------------------------------------
# Iter : 19510 / 20000, Time elapsed: 0.33 seconds, Loss: 494005888, EST: 0:02:43
# Iter : 19520 / 20000, Time elapsed: 0.33 seconds, Loss: 499617920, EST: 0:02:39
# Iter : 19530 / 20000, Time elapsed: 0.33 seconds, Loss: 520997920, EST: 0:02:35
# Iter : 19540 / 20000, Time elapsed: 0.33 seconds, Loss: 514952640, EST: 0:02:32
# Iter : 19550 / 20000, Time elapsed: 0.33 seconds, Loss: 602085440, EST: 0:02:30
# ----------------------------------------------------
# Details: iteration 19550, improvement: 0.16 percent, loss: 569614675
# content_loss: 398830325, style_loss_1: 4976378, style_loss_2: 71199334
# style_loss_3: 79296941, style_loss_4: 279499, tv_loss: 15032198
# ----------------------------------------------------
# Iter : 19560 / 20000, Time elapsed: 0.33 seconds, Loss: 577743872, EST: 0:02:25
# Iter : 19570 / 20000, Time elapsed: 0.33 seconds, Loss: 476926624, EST: 0:02:21
# Iter : 19580 / 20000, Time elapsed: 0.33 seconds, Loss: 532236384, EST: 0:02:19
# Iter : 19590 / 20000, Time elapsed: 0.33 seconds, Loss: 551147008, EST: 0:02:16
# Iter : 19600 / 20000, Time elapsed: 0.33 seconds, Loss: 438243232, EST: 0:02:11
# ----------------------------------------------------
# Details: iteration 19600, improvement: -20.69 percent, loss: 687452461
# content_loss: 445379750, style_loss_1: 6365847, style_loss_2: 78075738
# style_loss_3: 139951360, style_loss_4: 328423, tv_loss: 17351344
# ----------------------------------------------------
# Iter : 19610 / 20000, Time elapsed: 0.33 seconds, Loss: 506322560, EST: 0:02:08
# Iter : 19620 / 20000, Time elapsed: 0.33 seconds, Loss: 518890464, EST: 0:02:05
# Iter : 19630 / 20000, Time elapsed: 0.33 seconds, Loss: 574134144, EST: 0:02:03
# Iter : 19640 / 20000, Time elapsed: 0.33 seconds, Loss: 604361600, EST: 0:01:58
# Iter : 19650 / 20000, Time elapsed: 0.33 seconds, Loss: 528029728, EST: 0:01:56
# ----------------------------------------------------
# Details: iteration 19650, improvement: 16.21 percent, loss: 576012288
# content_loss: 426939600, style_loss_1: 3212323, style_loss_2: 43188851
# style_loss_3: 85908672, style_loss_4: 271910, tv_loss: 16490931
# ----------------------------------------------------
# Iter : 19660 / 20000, Time elapsed: 0.33 seconds, Loss: 567865280, EST: 0:01:53
# Iter : 19670 / 20000, Time elapsed: 0.33 seconds, Loss: 561045952, EST: 0:01:49
# Iter : 19680 / 20000, Time elapsed: 0.33 seconds, Loss: 583682816, EST: 0:01:45
# Iter : 19690 / 20000, Time elapsed: 0.33 seconds, Loss: 510527200, EST: 0:01:42
# Iter : 19700 / 20000, Time elapsed: 0.33 seconds, Loss: 531920672, EST: 0:01:39
# ----------------------------------------------------
# Details: iteration 19700, improvement: 0.56 percent, loss: 572781176
# content_loss: 430949650, style_loss_1: 9803010, style_loss_2: 41292762
# style_loss_3: 73878042, style_loss_4: 287025, tv_loss: 16570688
# ----------------------------------------------------
# Iter : 19710 / 20000, Time elapsed: 0.33 seconds, Loss: 535166912, EST: 0:01:36
# Iter : 19720 / 20000, Time elapsed: 0.33 seconds, Loss: 474216224, EST: 0:01:33
# Iter : 19730 / 20000, Time elapsed: 0.33 seconds, Loss: 469035488, EST: 0:01:29
# Iter : 19740 / 20000, Time elapsed: 0.33 seconds, Loss: 511938976, EST: 0:01:26
# Iter : 19750 / 20000, Time elapsed: 0.33 seconds, Loss: 499357888, EST: 0:01:23
# ----------------------------------------------------
# Details: iteration 19750, improvement: -2.34 percent, loss: 586169768
# content_loss: 427837500, style_loss_1: 4698056, style_loss_2: 53121440
# style_loss_3: 83982669, style_loss_4: 282901, tv_loss: 16247202
# ----------------------------------------------------
# Iter : 19760 / 20000, Time elapsed: 0.33 seconds, Loss: 556585088, EST: 0:01:19
# Iter : 19770 / 20000, Time elapsed: 0.33 seconds, Loss: 561399872, EST: 0:01:15
# Iter : 19780 / 20000, Time elapsed: 0.33 seconds, Loss: 500907552, EST: 0:01:12
# Iter : 19790 / 20000, Time elapsed: 0.33 seconds, Loss: 526273152, EST: 0:01:09
# Iter : 19800 / 20000, Time elapsed: 0.33 seconds, Loss: 466535424, EST: 0:01:06
# ----------------------------------------------------
# Details: iteration 19800, improvement: 3.90 percent, loss: 563311111
# content_loss: 414845850, style_loss_1: 4606460, style_loss_2: 48652870
# style_loss_3: 79049395, style_loss_4: 301450, tv_loss: 15855086
# ----------------------------------------------------
# Iter : 19810 / 20000, Time elapsed: 0.33 seconds, Loss: 530572928, EST: 0:01:02
# Iter : 19820 / 20000, Time elapsed: 0.33 seconds, Loss: 538044544, EST: 0:00:59
# Iter : 19830 / 20000, Time elapsed: 0.33 seconds, Loss: 606412288, EST: 0:00:56
# Iter : 19840 / 20000, Time elapsed: 0.33 seconds, Loss: 551638272, EST: 0:00:53
# Iter : 19850 / 20000, Time elapsed: 0.33 seconds, Loss: 538962432, EST: 0:00:49
# ----------------------------------------------------
# Details: iteration 19850, improvement: -0.41 percent, loss: 565596516
# content_loss: 409451600, style_loss_1: 6812984, style_loss_2: 55112614
# style_loss_3: 77927264, style_loss_4: 275366, tv_loss: 16016688
# ----------------------------------------------------
# Iter : 19860 / 20000, Time elapsed: 0.33 seconds, Loss: 633355712, EST: 0:00:46
# Iter : 19870 / 20000, Time elapsed: 0.33 seconds, Loss: 514291008, EST: 0:00:43
# Iter : 19880 / 20000, Time elapsed: 0.33 seconds, Loss: 545201600, EST: 0:00:39
# Iter : 19890 / 20000, Time elapsed: 0.33 seconds, Loss: 597635968, EST: 0:00:36
# Iter : 19900 / 20000, Time elapsed: 0.33 seconds, Loss: 473510656, EST: 0:00:33
# ----------------------------------------------------
# Details: iteration 19900, improvement: -1.20 percent, loss: 572390880
# content_loss: 434317850, style_loss_1: 2883196, style_loss_2: 39850560
# style_loss_3: 78845248, style_loss_4: 281433, tv_loss: 16212593
# ----------------------------------------------------
# Iter : 19910 / 20000, Time elapsed: 0.33 seconds, Loss: 505568640, EST: 0:00:29
# Iter : 19920 / 20000, Time elapsed: 0.33 seconds, Loss: 473419232, EST: 0:00:26
# Iter : 19930 / 20000, Time elapsed: 0.33 seconds, Loss: 462448448, EST: 0:00:23
# Iter : 19940 / 20000, Time elapsed: 0.33 seconds, Loss: 499452448, EST: 0:00:19
# Iter : 19950 / 20000, Time elapsed: 0.33 seconds, Loss: 436398976, EST: 0:00:16
# ----------------------------------------------------
# Details: iteration 19950, improvement: -2.36 percent, loss: 585904021
# content_loss: 412395050, style_loss_1: 4358254, style_loss_2: 67603200
# style_loss_3: 85472448, style_loss_4: 289716, tv_loss: 15785352
# ----------------------------------------------------
# Iter : 19960 / 20000, Time elapsed: 0.33 seconds, Loss: 483550528, EST: 0:00:13
# Iter : 19970 / 20000, Time elapsed: 0.33 seconds, Loss: 497095072, EST: 0:00:09
# Iter : 19980 / 20000, Time elapsed: 0.33 seconds, Loss: 594264320, EST: 0:00:06
# Iter : 19990 / 20000, Time elapsed: 0.33 seconds, Loss: 564164480, EST: 0:00:03
# Iter : 20000 / 20000, Time elapsed: 0.33 seconds, Loss: 460513120, EST: 0:00:00
# ----------------------------------------------------
# Details: iteration 20000, improvement: 2.56 percent, loss: 570923931
# content_loss: 428326550, style_loss_1: 3590558, style_loss_2: 42779315
# style_loss_3: 79773952, style_loss_4: 255781, tv_loss: 16197774
# ----------------------------------------------------
# Training ended. Time used: 4:07:18
# Saving models...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a97621364dd4> in <module>()
# ----> 1 train(options)
#
# <ipython-input-13-2e091646dd39> in train(options)
#     149     # Saving models
#     150     print("Saving models...")
# --> 151     model_eval = get_evaluate_model(width, height)
#     152     training_model_layers = {layer.name: layer for layer in training_model.layers}
#     153     for layer in model_eval.layers:
#
# NameError: name 'get_evaluate_model' is not defined
