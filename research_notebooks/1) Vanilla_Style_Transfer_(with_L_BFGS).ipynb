# %% [markdown]
# <a href="https://colab.research.google.com/github/Gooogr/Keras_Fast_Style_Transfer/blob/master/Vanilla_Style_Transfer_(with_L_BFGS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications import vgg19
from keras import backend as K

import numpy as np

from imageio import imwrite
import cv2 

import time

from scipy.optimize import fmin_l_bfgs_b

from matplotlib import pyplot as plt

from google.colab.patches import cv2_imshow   #instead of cv2.imshow
from google.colab import drive
# Out:
# Using TensorFlow backend.

# %% [markdown]
# [How to add data from google drive to collab file](https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92)
#
# [How to prevent google collab from disconnecting ](https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0)

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
target_image_path = '/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/dogs.jpg'
style_reference_image_path = '/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/night.jpg'
result_directory_path = '/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_results'

# %%
## uncomment to check images

## you can use 'load_img(file_path)' instead of cv2

# img = cv2.imread(target_image_path)
# cv2_imshow(img)

# img = cv2.imread(style_reference_image_path)
# cv2_imshow(img)

# %%
# Scale input image to VGG19 size
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)

# %%
# Вспомогательные функции
def preprocess_image(image_path):
    img = load_img(image_path, target_size = (img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis = 0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):    
    x[:, :, 0] += 103.939 # Нулевое центрирование путем удаления среднего значения пиксела из ImageNet.                          
    x[:, :, 1] += 116.779 # Отменяет преобразование выполненное vgg19.preprocess_input
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1] #BGR -> RGB
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# Настроим сеть VGG19.
# Она принимает на вход пакет из трех изображений:
# * Изображение с образцом стиля
# * Целевое изображение
# * Заготовка, куда будет помещен результат
#
# Изображения с образцом стиля и целью определяются как константы.

# %%
target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))
combination_image = K.placeholder((1, img_height, img_width, 3))

input_tensor = K.concatenate([target_image, style_reference_image, combination_image], axis = 0)

model = vgg19.VGG19(input_tensor = input_tensor,
                    weights = 'imagenet',
                    include_top = False)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %% [markdown]
# Определим функцию потери. Она характеризуется функциями потерь содержимого, стиля и общей потери вариации.

# %%
def content_loss(base, combination):
    '''
    Функция потерь содержимого.
    '''
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    '''
    Вспомогательная функция. Вычисляет матрицу Грама для корреляционной матрицы.
    http://pmpu.ru/vf4/dets/gram
    '''
    # K.permute_dimensions - Permutes axes in a tensor. https://www.tensorflow.org/api_docs/python/tf/keras/backend/permute_dimensions
    # K.batch_flatten - Turn a nD tensor into a 2D tensor with same 0th dimension. https://www.tensorflow.org/api_docs/python/tf/keras/backend/batch_flatten
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

def style_loss(style, combination):
    '''
    Функция потерь стиля
    '''
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    '''
    Фунция общей потери вариации, стимулирует пространственную целостность итогового изображения, 
    позволяет избежать мозаичного эффекта.
    Можно интерпретировать как регуляризацию потерь.
    '''
    a = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :]) # Сдвиг в 1 пиксель по высоте\ширине
    b = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %% [markdown]
# Для вычисления потери содержимого используется только один верхний слой block5_conv2.<br>
# Для вычисления потери стиля - нижние слои из каждого сверточного блока.<br>
# Общая потеря вариации добавляется в конце.

# %%
# Определение общей потери
output_dict = dict([(layer.name, layer.output) for layer in model.layers])
content_layer = 'block5_conv2'
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025 # Чем больше - тем больше походит итоговое изображение на целевое

loss = K.variable(0.)

# content loss part
layer_features = output_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features, combination_features)

# style loss part
for layer_name in style_layers:
    layer_features = output_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl

# variation loss part
loss += total_variation_weight * total_variation_loss(combination_image)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %% [markdown]
# Настройка процесса градиентного спуска.
#
# Градиентный спуск выполняется с помощью алгоритма L - BFGS, как в и оригинальной статье.
# Этот алгоритм реализован в пакете SciPy, однако есть 2 нюанса:<br>
# 1) Алгоритм требует передачи значений функции потерь и градиентов в виде двух отдельных функций.<br>
# 2) Может применятся только к плоским векторам.
#
# Для решения проблемы напишем класс-оберту, который будет вычислять значения потерь и градиентов одновременно, возвращать значение потерь при первом обращении и кэшировать значение градиентов при первом обращении.

# %%
grads = K.gradients(loss, combination_image)[0]

fetch_loss_and_grads = K.function([combination_image], [loss, grads])

class Evaluator(object):
    
    def __init__(self):
        self.loss_value = None
        self.grads_values = None
    
    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value
    
    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values
    
evaluator = Evaluator()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# Запускаем весь процесс

# %%
result_prefix = 'result'
iterations = 1000

x = preprocess_image(target_image_path)
x = x.flatten()

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime = evaluator.grads, maxfun = 20)
    print('Current loss value:', min_val)
    
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_directory_path + result_prefix + '_at_iteration_%d.png' % i
    imwrite(fname, img)
    print('Image saved as', fname)
    end_time = time.time()
    print('Iteration %d complited in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 3204934400.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_0.png
# Iteration 0 complited in 24s
# Start of iteration 1
# Current loss value: 1125598700.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_1.png
# Iteration 1 complited in 16s
# Start of iteration 2
# Current loss value: 603369540.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_2.png
# Iteration 2 complited in 16s
# Start of iteration 3
# Current loss value: 436145180.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_3.png
# Iteration 3 complited in 16s
# Start of iteration 4
# Current loss value: 329349980.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_4.png
# Iteration 4 complited in 16s
# Start of iteration 5
# Current loss value: 273540600.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_5.png
# Iteration 5 complited in 16s
# Start of iteration 6
# Current loss value: 234775970.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_6.png
# Iteration 6 complited in 16s
# Start of iteration 7
# Current loss value: 209463170.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_7.png
# Iteration 7 complited in 16s
# Start of iteration 8
# Current loss value: 190203760.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_8.png
# Iteration 8 complited in 16s
# Start of iteration 9
# Current loss value: 174901620.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_9.png
# Iteration 9 complited in 16s
# Start of iteration 10
# Current loss value: 161062510.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_10.png
# Iteration 10 complited in 16s
# Start of iteration 11
# Current loss value: 151099150.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_11.png
# Iteration 11 complited in 16s
# Start of iteration 12
# Current loss value: 139622450.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_12.png
# Iteration 12 complited in 16s
# Start of iteration 13
# Current loss value: 131105880.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_13.png
# Iteration 13 complited in 16s
# Start of iteration 14
# Current loss value: 122587710.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_14.png
# Iteration 14 complited in 16s
# Start of iteration 15
# Current loss value: 116903780.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_15.png
# Iteration 15 complited in 16s
# Start of iteration 16
# Current loss value: 112053896.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_16.png
# Iteration 16 complited in 16s
# Start of iteration 17
# Current loss value: 108087590.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_17.png
# Iteration 17 complited in 16s
# Start of iteration 18
# Current loss value: 105633930.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_18.png
# Iteration 18 complited in 16s
# Start of iteration 19
# Current loss value: 103216990.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_19.png
# Iteration 19 complited in 16s
# Start of iteration 20
# Current loss value: 99888776.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_20.png
# Iteration 20 complited in 16s
# Start of iteration 21
# Current loss value: 96531770.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_21.png
# Iteration 21 complited in 16s
# Start of iteration 22
# Current loss value: 94535580.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_22.png
# Iteration 22 complited in 16s
# Start of iteration 23
# Current loss value: 92872940.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_23.png
# Iteration 23 complited in 16s
# Start of iteration 24
# Current loss value: 90724790.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_24.png
# Iteration 24 complited in 16s
# Start of iteration 25
# Current loss value: 89071230.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_25.png
# Iteration 25 complited in 16s
# Start of iteration 26
# Current loss value: 85807940.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_26.png
# Iteration 26 complited in 16s
# Start of iteration 27
# Current loss value: 83434240.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_27.png
# Iteration 27 complited in 16s
# Start of iteration 28
# Current loss value: 82277120.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_28.png
# Iteration 28 complited in 16s
# Start of iteration 29
# Current loss value: 81169950.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_29.png
# Iteration 29 complited in 17s
# Start of iteration 30
# Current loss value: 80263110.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_30.png
# Iteration 30 complited in 16s
# Start of iteration 31
# Current loss value: 79143330.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_31.png
# Iteration 31 complited in 17s
# Start of iteration 32
# Current loss value: 78260330.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_32.png
# Iteration 32 complited in 16s
# Start of iteration 33
# Current loss value: 77539970.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_33.png
# Iteration 33 complited in 16s
# Start of iteration 34
# Current loss value: 76584100.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_34.png
# Iteration 34 complited in 16s
# Start of iteration 35
# Current loss value: 75841780.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_35.png
# Iteration 35 complited in 16s
# Start of iteration 36
# Current loss value: 75030000.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_36.png
# Iteration 36 complited in 16s
# Start of iteration 37
# Current loss value: 74342330.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_37.png
# Iteration 37 complited in 16s
# Start of iteration 38
# Current loss value: 73642296.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_38.png
# Iteration 38 complited in 16s
# Start of iteration 39
# Current loss value: 72997630.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_39.png
# Iteration 39 complited in 16s
# Start of iteration 40
# Current loss value: 72479670.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_40.png
# Iteration 40 complited in 16s
# Start of iteration 41
# Current loss value: 71879540.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_41.png
# Iteration 41 complited in 17s
# Start of iteration 42
# Current loss value: 71242450.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_42.png
# Iteration 42 complited in 17s
# Start of iteration 43
# Current loss value: 70619864.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_43.png
# Iteration 43 complited in 16s
# Start of iteration 44
# Current loss value: 70078710.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_44.png
# Iteration 44 complited in 17s
# Start of iteration 45
# Current loss value: 69459544.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_45.png
# Iteration 45 complited in 16s
# Start of iteration 46
# Current loss value: 68881336.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_46.png
# Iteration 46 complited in 16s
# Start of iteration 47
# Current loss value: 68209400.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_47.png
# Iteration 47 complited in 16s
# Start of iteration 48
# Current loss value: 67567810.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_48.png
# Iteration 48 complited in 16s
# Start of iteration 49
# Current loss value: 67170540.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_49.png
# Iteration 49 complited in 16s
# Start of iteration 50
# Current loss value: 66648310.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_50.png
# Iteration 50 complited in 16s
# Start of iteration 51
# Current loss value: 66217240.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_51.png
# Iteration 51 complited in 16s
# Start of iteration 52
# Current loss value: 65835270.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_52.png
# Iteration 52 complited in 16s
# Start of iteration 53
# Current loss value: 65504756.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_53.png
# Iteration 53 complited in 16s
# Start of iteration 54
# Current loss value: 65093692.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_54.png
# Iteration 54 complited in 16s
# Start of iteration 55
# Current loss value: 64718664.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_55.png
# Iteration 55 complited in 17s
# Start of iteration 56
# Current loss value: 64343772.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_56.png
# Iteration 56 complited in 16s
# Start of iteration 57
# Current loss value: 63995610.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_57.png
# Iteration 57 complited in 16s
# Start of iteration 58
# Current loss value: 63630164.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_58.png
# Iteration 58 complited in 16s
# Start of iteration 59
# Current loss value: 63321664.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_59.png
# Iteration 59 complited in 16s
# Start of iteration 60
# Current loss value: 62926764.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_60.png
# Iteration 60 complited in 19s
# Start of iteration 61
# Current loss value: 62543590.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_61.png
# Iteration 61 complited in 17s
# Start of iteration 62
# Current loss value: 62236580.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_62.png
# Iteration 62 complited in 16s
# Start of iteration 63
# Current loss value: 61944748.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_63.png
# Iteration 63 complited in 16s
# Start of iteration 64
# Current loss value: 61670796.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_64.png
# Iteration 64 complited in 16s
# Start of iteration 65
# Current loss value: 61429770.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_65.png
# Iteration 65 complited in 16s
# Start of iteration 66
# Current loss value: 61080628.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_66.png
# Iteration 66 complited in 16s
# Start of iteration 67
# Current loss value: 60738250.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_67.png
# Iteration 67 complited in 16s
# Start of iteration 68
# Current loss value: 60415708.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_68.png
# Iteration 68 complited in 16s
# Start of iteration 69
# Current loss value: 60107470.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_69.png
# Iteration 69 complited in 16s
# Start of iteration 70
# Current loss value: 59834892.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_70.png
# Iteration 70 complited in 16s
# Start of iteration 71
# Current loss value: 59590940.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_71.png
# Iteration 71 complited in 16s
# Start of iteration 72
# Current loss value: 59205790.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_72.png
# Iteration 72 complited in 16s
# Start of iteration 73
# Current loss value: 58863932.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_73.png
# Iteration 73 complited in 17s
# Start of iteration 74
# Current loss value: 58645096.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_74.png
# Iteration 74 complited in 16s
# Start of iteration 75
# Current loss value: 58417904.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_75.png
# Iteration 75 complited in 16s
# Start of iteration 76
# Current loss value: 58216436.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_76.png
# Iteration 76 complited in 16s
# Start of iteration 77
# Current loss value: 58026960.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_77.png
# Iteration 77 complited in 16s
# Start of iteration 78
# Current loss value: 57698124.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_78.png
# Iteration 78 complited in 16s
# Start of iteration 79
# Current loss value: 57405640.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_79.png
# Iteration 79 complited in 16s
# Start of iteration 80
# Current loss value: 57107544.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_80.png
# Iteration 80 complited in 16s
# Start of iteration 81
# Current loss value: 56842784.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_81.png
# Iteration 81 complited in 16s
# Start of iteration 82
# Current loss value: 56550284.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_82.png
# Iteration 82 complited in 16s
# Start of iteration 83
# Current loss value: 56288476.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_83.png
# Iteration 83 complited in 17s
# Start of iteration 84
# Current loss value: 55994708.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_84.png
# Iteration 84 complited in 17s
# Start of iteration 85
# Current loss value: 55711372.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_85.png
# Iteration 85 complited in 16s
# Start of iteration 86
# Current loss value: 55310676.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_86.png
# Iteration 86 complited in 16s
# Start of iteration 87
# Current loss value: 54890224.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_87.png
# Iteration 87 complited in 16s
# Start of iteration 88
# Current loss value: 54700390.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_88.png
# Iteration 88 complited in 16s
# Start of iteration 89
# Current loss value: 54527244.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_89.png
# Iteration 89 complited in 16s
# Start of iteration 90
# Current loss value: 54338370.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_90.png
# Iteration 90 complited in 16s
# Start of iteration 91
# Current loss value: 54149280.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_91.png
# Iteration 91 complited in 16s
# Start of iteration 92
# Current loss value: 53977244.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_92.png
# Iteration 92 complited in 16s
# Start of iteration 93
# Current loss value: 53770496.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_93.png
# Iteration 93 complited in 16s
# Start of iteration 94
# Current loss value: 53586508.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_94.png
# Iteration 94 complited in 16s
# Start of iteration 95
# Current loss value: 53407124.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_95.png
# Iteration 95 complited in 16s
# Start of iteration 96
# Current loss value: 53247172.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_96.png
# Iteration 96 complited in 17s
# Start of iteration 97
# Current loss value: 53104020.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_97.png
# Iteration 97 complited in 16s
# Start of iteration 98
# Current loss value: 52944524.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_98.png
# Iteration 98 complited in 16s
# Start of iteration 99
# Current loss value: 52781388.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_99.png
# Iteration 99 complited in 16s
# Start of iteration 100
# Current loss value: 52630704.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_100.png
# Iteration 100 complited in 16s
# Start of iteration 101
# Current loss value: 52425376.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_101.png
# Iteration 101 complited in 16s
# Start of iteration 102
# Current loss value: 52294960.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_102.png
# Iteration 102 complited in 16s
# Start of iteration 103
# Current loss value: 52128132.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_103.png
# Iteration 103 complited in 17s
# Start of iteration 104
# Current loss value: 51946240.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_104.png
# Iteration 104 complited in 17s
# Start of iteration 105
# Current loss value: 51743890.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_105.png
# Iteration 105 complited in 17s
# Start of iteration 106
# Current loss value: 51544148.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_106.png
# Iteration 106 complited in 16s
# Start of iteration 107
# Current loss value: 51388050.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_107.png
# Iteration 107 complited in 16s
# Start of iteration 108
# Current loss value: 51237836.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_108.png
# Iteration 108 complited in 17s
# Start of iteration 109
# Current loss value: 51088724.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_109.png
# Iteration 109 complited in 17s
# Start of iteration 110
# Current loss value: 50947304.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_110.png
# Iteration 110 complited in 17s
# Start of iteration 111
# Current loss value: 50831816.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_111.png
# Iteration 111 complited in 16s
# Start of iteration 112
# Current loss value: 50707990.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_112.png
# Iteration 112 complited in 16s
# Start of iteration 113
# Current loss value: 50587372.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_113.png
# Iteration 113 complited in 17s
# Start of iteration 114
# Current loss value: 50481948.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_114.png
# Iteration 114 complited in 16s
# Start of iteration 115
# Current loss value: 50384412.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_115.png
# Iteration 115 complited in 16s
# Start of iteration 116
# Current loss value: 50268616.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_116.png
# Iteration 116 complited in 17s
# Start of iteration 117
# Current loss value: 50139556.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_117.png
# Iteration 117 complited in 17s
# Start of iteration 118
# Current loss value: 50026224.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_118.png
# Iteration 118 complited in 17s
# Start of iteration 119
# Current loss value: 49914330.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_119.png
# Iteration 119 complited in 16s
# Start of iteration 120
# Current loss value: 49807224.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_120.png
# Iteration 120 complited in 16s
# Start of iteration 121
# Current loss value: 49695964.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_121.png
# Iteration 121 complited in 17s
# Start of iteration 122
# Current loss value: 49573548.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_122.png
# Iteration 122 complited in 17s
# Start of iteration 123
# Current loss value: 49448804.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_123.png
# Iteration 123 complited in 16s
# Start of iteration 124
# Current loss value: 49326876.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_124.png
# Iteration 124 complited in 16s
# Start of iteration 125
# Current loss value: 49220280.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_125.png
# Iteration 125 complited in 16s
# Start of iteration 126
# Current loss value: 49052796.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_126.png
# Iteration 126 complited in 16s
# Start of iteration 127
# Current loss value: 48942220.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_127.png
# Iteration 127 complited in 16s
# Start of iteration 128
# Current loss value: 48816020.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_128.png
# Iteration 128 complited in 16s
# Start of iteration 129
# Current loss value: 48665640.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_129.png
# Iteration 129 complited in 16s
# Start of iteration 130
# Current loss value: 48554652.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_130.png
# Iteration 130 complited in 16s
# Start of iteration 131
# Current loss value: 48431650.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_131.png
# Iteration 131 complited in 16s
# Start of iteration 132
# Current loss value: 48336460.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration
0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_201.png
# Iteration 201 complited in 16s
# Start of iteration 202
# Current loss value: 43134430.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_202.png
# Iteration 202 complited in 16s
# Start of iteration 203
# Current loss value: 43072196.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_203.png
# Iteration 203 complited in 17s
# Start of iteration 204
# Current loss value: 43030384.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_204.png
# Iteration 204 complited in 16s
# Start of iteration 205
# Current loss value: 42992080.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_205.png
# Iteration 205 complited in 16s
# Start of iteration 206
# Current loss value: 42950120.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_206.png
# Iteration 206 complited in 16s
# Start of iteration 207
# Current loss value: 42898210.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_207.png
# Iteration 207 complited in 17s
# Start of iteration 208
# Current loss value: 42849860.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_208.png
# Iteration 208 complited in 16s
# Start of iteration 209
# Current loss value: 42805736.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_209.png
# Iteration 209 complited in 16s
# Start of iteration 210
# Current loss value: 42758216.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_210.png
# Iteration 210 complited in 16s
# Start of iteration 211
# Current loss value: 42715412.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_211.png
# Iteration 211 complited in 16s
# Start of iteration 212
# Current loss value: 42663716.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_212.png
# Iteration 212 complited in 17s
# Start of iteration 213
# Current loss value: 42613924.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_213.png
# Iteration 213 complited in 16s
# Start of iteration 214
# Current loss value: 42574070.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_214.png
# Iteration 214 complited in 16s
# Start of iteration 215
# Current loss value: 42537190.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_215.png
# Iteration 215 complited in 16s
# Start of iteration 216
# Current loss value: 42488824.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_216.png
# Iteration 216 complited in 16s
# Start of iteration 217
# Current loss value: 42432916.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_217.png
# Iteration 217 complited in 16s
# Start of iteration 218
# Current loss value: 42373404.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_218.png
# Iteration 218 complited in 16s
# Start of iteration 219
# Current loss value: 42319730.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_219.png
# Iteration 219 complited in 17s
# Start of iteration 220
# Current loss value: 42255910.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_220.png
# Iteration 220 complited in 16s
# Start of iteration 221
# Current loss value: 42182068.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_221.png
# Iteration 221 complited in 16s
# Start of iteration 222
# Current loss value: 42111924.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_222.png
# Iteration 222 complited in 16s
# Start of iteration 223
# Current loss value: 42045884.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_223.png
# Iteration 223 complited in 16s
# Start of iteration 224
# Current loss value: 42004176.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_224.png
# Iteration 224 complited in 16s
# Start of iteration 225
# Current loss value: 41958900.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_225.png
# Iteration 225 complited in 17s
# Start of iteration 226
# Current loss value: 41914932.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_226.png
# Iteration 226 complited in 16s
# Start of iteration 227
# Current loss value: 41877044.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_227.png
# ...
# Iteration 924 complited in 16s
# Start of iteration 925
# Current loss value: 31719418.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_925.png
# Iteration 925 complited in 16s
# Start of iteration 926
# Current loss value: 31715400.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_926.png
# Iteration 926 complited in 16s
# Start of iteration 927
# Current loss value: 31711614.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_927.png
# Iteration 927 complited in 16s
# Start of iteration 928
# Current loss value: 31705730.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_928.png
# Iteration 928 complited in 16s
# Start of iteration 929
# Current loss value: 31697600.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_929.png
# Iteration 929 complited in 16s
# Start of iteration 930
# Current loss value: 31692458.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_930.png
# Iteration 930 complited in 16s
# Start of iteration 931
# Current loss value: 31687232.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_931.png
# Iteration 931 complited in 16s
# Start of iteration 932
# Current loss value: 31683066.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration
0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_966.png
# Iteration 966 complited in 16s
# Start of iteration 967
# Current loss value: 31533624.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_967.png
# Iteration 967 complited in 16s
# Start of iteration 968
# Current loss value: 31526570.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_968.png
# Iteration 968 complited in 16s
# Start of iteration 969
# Current loss value: 31521750.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_969.png
# Iteration 969 complited in 16s
# Start of iteration 970
# Current loss value: 31516030.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_970.png
# Iteration 970 complited in 16s
# Start of iteration 971
# Current loss value: 31511706.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_971.png
# Iteration 971 complited in 16s
# Start of iteration 972
# Current loss value: 31507250.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_972.png
# Iteration 972 complited in 16s
# Start of iteration 973
# Current loss value: 31503880.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_973.png
# Iteration 973 complited in 16s
# Start of iteration 974
# Current loss value: 31499414.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_974.png
# Iteration 974 complited in 16s
# Start of iteration 975
# Current loss value: 31495528.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_975.png
# Iteration 975 complited in 16s
# Start of iteration 976
# Current loss value: 31491626.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_976.png
# Iteration 976 complited in 16s
# Start of iteration 977
# Current loss value: 31487248.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_977.png
# Iteration 977 complited in 16s
# Start of iteration 978
# Current loss value: 31482920.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_978.png
# Iteration 978 complited in 16s
# Start of iteration 979
# Current loss value: 31477348.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_979.png
# Iteration 979 complited in 16s
# Start of iteration 980
# Current loss value: 31473448.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_980.png
# Iteration 980 complited in 16s
# Start of iteration 981
# Current loss value: 31468786.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_981.png
# Iteration 981 complited in 16s
# Start of iteration 982
# Current loss value: 31464706.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_982.png
# Iteration 982 complited in 16s
# Start of iteration 983
# Current loss value: 31459952.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_983.png
# Iteration 983 complited in 16s
# Start of iteration 984
# Current loss value: 31456302.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_984.png
# Iteration 984 complited in 16s
# Start of iteration 985
# Current loss value: 31452606.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_985.png
# Iteration 985 complited in 16s
# Start of iteration 986
# Current loss value: 31447490.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_986.png
# Iteration 986 complited in 16s
# Start of iteration 987
# Current loss value: 31440350.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_987.png
# Iteration 987 complited in 16s
# Start of iteration 988
# Current loss value: 31434982.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_988.png
# Iteration 988 complited in 16s
# Start of iteration 989
# Current loss value: 31428482.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_989.png
# Iteration 989 complited in 16s
# Start of iteration 990
# Current loss value: 31424262.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_990.png
# Iteration 990 complited in 16s
# Start of iteration 991
# Current loss value: 31420204.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_991.png
# Iteration 991 complited in 16s
# Start of iteration 992
# Current loss value: 31416474.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_992.png
# Iteration 992 complited in 16s
# Start of iteration 993
# Current loss value: 31412950.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_993.png
# Iteration 993 complited in 16s
# Start of iteration 994
# Current loss value: 31408832.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_994.png
# Iteration 994 complited in 16s
# Start of iteration 995
# Current loss value: 31404978.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_995.png
# Iteration 995 complited in 16s
# Start of iteration 996
# Current loss value: 31400576.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_996.png
# Iteration 996 complited in 16s
# Start of iteration 997
# Current loss value: 31395788.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_997.png
# Iteration 997 complited in 16s
# Start of iteration 998
# Current loss value: 31388090.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_998.png
# Iteration 998 complited in 16s
# Start of iteration 999
# Current loss value: 31384818.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/epochs_resultsresult_at_iteration_999.png
# Iteration 999 complited in 16s
