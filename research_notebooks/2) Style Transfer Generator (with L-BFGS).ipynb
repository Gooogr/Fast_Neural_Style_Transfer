# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications import vgg19
from keras import backend as K

import numpy as np

from imageio import imwrite
import cv2 

import time

from scipy.optimize import fmin_l_bfgs_b

from matplotlib import pyplot as plt

from google.colab.patches import cv2_imshow   #instead of cv2.imshow
from google.colab import drive

import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# [How to add data from google drive to collab file](https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92)
#
# [How to prevent google collab from disconnecting ](https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0)

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
target_imgs_list = os.listdir('/content/drive/My Drive/datasets/autoencoder_dataset')

target_names = [name.split('.')[0] for name in target_imgs_list]
target_abs_pathes = [os.path.join('/content/drive/My Drive/datasets/autoencoder_dataset', name +'.jpg') for name in target_names]

target_dict = dict(zip(target_names, target_abs_pathes ))
target_dict
# Out:
# {'bird': '/content/drive/My Drive/datasets/autoencoder_dataset/bird.jpg',
#  'bridge': '/content/drive/My Drive/datasets/autoencoder_dataset/bridge.jpg',
#  'castle': '/content/drive/My Drive/datasets/autoencoder_dataset/castle.jpg',
#  'dear': '/content/drive/My Drive/datasets/autoencoder_dataset/dear.jpg',
#  'eagle': '/content/drive/My Drive/datasets/autoencoder_dataset/eagle.jpg',
#  'fish': '/content/drive/My Drive/datasets/autoencoder_dataset/fish.jpg',
#  'forest': '/content/drive/My Drive/datasets/autoencoder_dataset/forest.jpg',
#  'lori': '/content/drive/My Drive/datasets/autoencoder_dataset/lori.jpg',
#  'mountain': '/content/drive/My Drive/datasets/autoencoder_dataset/mountain.jpg',
#  'picture': '/content/drive/My Drive/datasets/autoencoder_dataset/picture.jpg',
#  'sea': '/content/drive/My Drive/datasets/autoencoder_dataset/sea.jpg',
#  'space': '/content/drive/My Drive/datasets/autoencoder_dataset/space.jpg',
#  'sunset': '/content/drive/My Drive/datasets/autoencoder_dataset/sunset.jpg',
#  'whale': '/content/drive/My Drive/datasets/autoencoder_dataset/whale.jpg',
#  'woman': '/content/drive/My Drive/datasets/autoencoder_dataset/woman.jpg'}

# %%
key = 'picture'

# %%
target_image_path = target_dict[key]

style_reference_image_path = '/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img/night.jpg'

try:
  os.mkdir('/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/' + key)
  result_directory_path = '/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/' + key + '/'
except:
   result_directory_path = '/content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/' + key+ '/'

# %%
## uncomment to check images

## you can use 'load_img(file_path)' instead of cv2

img = cv2.imread(target_image_path)
cv2_imshow(img)

# img = cv2.imread(style_reference_image_path)
# cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Scale input image to VGG19 size
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)

# %%
# Вспомогательные функции
def preprocess_image(image_path):
    img = load_img(image_path, target_size = (img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis = 0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):    
    x[:, :, 0] += 103.939 # Нулевое центрирование путем удаления среднего значения пиксела из ImageNet.                          
    x[:, :, 1] += 116.779 # Отменяет преобразование выполненное vgg19.preprocess_input
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1] #BGR -> RGB
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# Настроим сеть VGG19.
# Она принимает на вход пакет из трех изображений:
# * Изображение с образцом стиля
# * Целевое изображение
# * Заготовка, куда будет помещен результат
#
# Изображения с образцом стиля и целью определяются как константы.

# %%
target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))
combination_image = K.placeholder((1, img_height, img_width, 3))

input_tensor = K.concatenate([target_image, style_reference_image, combination_image], axis = 0)

model = vgg19.VGG19(input_tensor = input_tensor,
                    weights = 'imagenet',
                    include_top = False)

# %% [markdown]
# Определим функцию потери. Она характеризуется функциями потерь содержимого, стиля и общей потери вариации.

# %%
def content_loss(base, combination):
    '''
    Функция потерь содержимого.
    '''
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    '''
    Вспомогательная функция. Вычисляет матрицу Грама для корреляционной матрицы.
    http://pmpu.ru/vf4/dets/gram
    '''
    # K.permute_dimensions - Permutes axes in a tensor. https://www.tensorflow.org/api_docs/python/tf/keras/backend/permute_dimensions
    # K.batch_flatten - Turn a nD tensor into a 2D tensor with same 0th dimension. https://www.tensorflow.org/api_docs/python/tf/keras/backend/batch_flatten
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

def style_loss(style, combination):
    '''
    Функция потерь стиля
    '''
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    '''
    Фунция общей потери вариации, стимулирует пространственную целостность итогового изображения, 
    позволяет избежать мозаичного эффекта.
    Можно интерпретировать как регуляризацию потерь.
    '''
    a = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :]) # Сдвиг в 1 пиксель по высоте\ширине
    b = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %% [markdown]
# Для вычисления потери содержимого используется только один верхний слой block5_conv2.<br>
# Для вычисления потери стиля - нижние слои из каждого сверточного блока.<br>
# Общая потеря вариации добавляется в конце.

# %%
# Определение общей потери
output_dict = dict([(layer.name, layer.output) for layer in model.layers])
content_layer = 'block5_conv2'
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025 # Чем больше - тем больше походит итоговое изображение на целевое

loss = K.variable(0.)

# content loss part
layer_features = output_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features, combination_features)

# style loss part
for layer_name in style_layers:
    layer_features = output_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl

# variation loss part
loss += total_variation_weight * total_variation_loss(combination_image)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %% [markdown]
# Настройка процесса градиентного спуска.
#
# Градиентный спуск выполняется с помощью алгоритма L - BFGS, как в и оригинальной статье.
# Этот алгоритм реализован в пакете SciPy, однако есть 2 нюанса:<br>
# 1) Алгоритм требует передачи значений функции потерь и градиентов в виде двух отдельных функций.<br>
# 2) Может применятся только к плоским векторам.
#
# Для решения проблемы напишем класс-оберту, который будет вычислять значения потерь и градиентов одновременно, возвращать значение потерь при первом обращении и кэшировать значение градиентов при первом обращении.

# %%
grads = K.gradients(loss, combination_image)[0]

fetch_loss_and_grads = K.function([combination_image], [loss, grads])

class Evaluator(object):
    
    def __init__(self):
        self.loss_value = None
        self.grads_values = None
    
    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value
    
    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values
    
evaluator = Evaluator()

# %% [markdown]
# Запускаем весь процесс

# %%
result_prefix = 'result'
iterations = 150

x = preprocess_image(target_image_path)
x = x.flatten()

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime = evaluator.grads, maxfun = 20)
    print('Current loss value:', min_val)
    
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_directory_path + result_prefix + '_at_iteration_%d.png' % i
    if i == 0 or (i+1) % 10 == 0:
      imwrite(fname, img)
      print('Image saved as', fname)
      end_time = time.time()
      print('Iteration %d complited in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 3755417600.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_0.png
# Iteration 0 complited in 12s
# Start of iteration 1
# Current loss value: 1419536000.0
# Start of iteration 2
# Current loss value: 832843900.0
# Start of iteration 3
# Current loss value: 614400800.0
# Start of iteration 4
# Current loss value: 493008420.0
# Start of iteration 5
# Current loss value: 418824800.0
# Start of iteration 6
# Current loss value: 354716450.0
# Start of iteration 7
# Current loss value: 304809200.0
# Start of iteration 8
# Current loss value: 274101250.0
# Start of iteration 9
# Current loss value: 251216540.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_9.png
# Iteration 9 complited in 8s
# Start of iteration 10
# Current loss value: 230062860.0
# Start of iteration 11
# Current loss value: 215429620.0
# Start of iteration 12
# Current loss value: 202731180.0
# Start of iteration 13
# Current loss value: 192179680.0
# Start of iteration 14
# Current loss value: 183051300.0
# Start of iteration 15
# Current loss value: 175942620.0
# Start of iteration 16
# Current loss value: 166073740.0
# Start of iteration 17
# Current loss value: 157656210.0
# Start of iteration 18
# Current loss value: 146876060.0
# Start of iteration 19
# Current loss value: 139416600.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_19.png
# Iteration 19 complited in 9s
# Start of iteration 20
# Current loss value: 134891250.0
# Start of iteration 21
# Current loss value: 130872170.0
# Start of iteration 22
# Current loss value: 128074060.0
# Start of iteration 23
# Current loss value: 125691450.0
# Start of iteration 24
# Current loss value: 122419040.0
# Start of iteration 25
# Current loss value: 119551160.0
# Start of iteration 26
# Current loss value: 117234770.0
# Start of iteration 27
# Current loss value: 114544360.0
# Start of iteration 28
# Current loss value: 112129660.0
# Start of iteration 29
# Current loss value: 109836330.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_29.png
# Iteration 29 complited in 9s
# Start of iteration 30
# Current loss value: 107803680.0
# Start of iteration 31
# Current loss value: 106102680.0
# Start of iteration 32
# Current loss value: 104499780.0
# Start of iteration 33
# Current loss value: 102951260.0
# Start of iteration 34
# Current loss value: 101583430.0
# Start of iteration 35
# Current loss value: 99999016.0
# Start of iteration 36
# Current loss value: 98438840.0
# Start of iteration 37
# Current loss value: 97245080.0
# Start of iteration 38
# Current loss value: 95669350.0
# Start of iteration 39
# Current loss value: 94401700.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_39.png
# Iteration 39 complited in 8s
# Start of iteration 40
# Current loss value: 93244860.0
# Start of iteration 41
# Current loss value: 92202264.0
# Start of iteration 42
# Current loss value: 90179224.0
# Start of iteration 43
# Current loss value: 88466950.0
# Start of iteration 44
# Current loss value: 87495060.0
# Start of iteration 45
# Current loss value: 86708456.0
# Start of iteration 46
# Current loss value: 85971280.0
# Start of iteration 47
# Current loss value: 85025660.0
# Start of iteration 48
# Current loss value: 84276680.0
# Start of iteration 49
# Current loss value: 83157290.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_49.png
# Iteration 49 complited in 9s
# Start of iteration 50
# Current loss value: 82135000.0
# Start of iteration 51
# Current loss value: 81154990.0
# Start of iteration 52
# Current loss value: 80367864.0
# Start of iteration 53
# Current loss value: 79527300.0
# Start of iteration 54
# Current loss value: 78838140.0
# Start of iteration 55
# Current loss value: 78088776.0
# Start of iteration 56
# Current loss value: 77381144.0
# Start of iteration 57
# Current loss value: 76775340.0
# Start of iteration 58
# Current loss value: 76232630.0
# Start of iteration 59
# Current loss value: 75494710.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_59.png
# Iteration 59 complited in 9s
# Start of iteration 60
# Current loss value: 74846984.0
# Start of iteration 61
# Current loss value: 74373780.0
# Start of iteration 62
# Current loss value: 73941810.0
# Start of iteration 63
# Current loss value: 73554270.0
# Start of iteration 64
# Current loss value: 73120060.0
# Start of iteration 65
# Current loss value: 72724340.0
# Start of iteration 66
# Current loss value: 72399260.0
# Start of iteration 67
# Current loss value: 72006170.0
# Start of iteration 68
# Current loss value: 71669310.0
# Start of iteration 69
# Current loss value: 71179176.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_69.png
# Iteration 69 complited in 9s
# Start of iteration 70
# Current loss value: 70724600.0
# Start of iteration 71
# Current loss value: 70363070.0
# Start of iteration 72
# Current loss value: 70056690.0
# Start of iteration 73
# Current loss value: 69608536.0
# Start of iteration 74
# Current loss value: 69242670.0
# Start of iteration 75
# Current loss value: 68945730.0
# Start of iteration 76
# Current loss value: 68692184.0
# Start of iteration 77
# Current loss value: 68373810.0
# Start of iteration 78
# Current loss value: 68090420.0
# Start of iteration 79
# Current loss value: 67767360.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_79.png
# Iteration 79 complited in 9s
# Start of iteration 80
# Current loss value: 67420620.0
# Start of iteration 81
# Current loss value: 67188820.0
# Start of iteration 82
# Current loss value: 66826850.0
# Start of iteration 83
# Current loss value: 66517530.0
# Start of iteration 84
# Current loss value: 66232410.0
# Start of iteration 85
# Current loss value: 65956504.0
# Start of iteration 86
# Current loss value: 65587756.0
# Start of iteration 87
# Current loss value: 65235170.0
# Start of iteration 88
# Current loss value: 64974212.0
# Start of iteration 89
# Current loss value: 64733804.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_89.png
# Iteration 89 complited in 9s
# Start of iteration 90
# Current loss value: 64392796.0
# Start of iteration 91
# Current loss value: 64121532.0
# Start of iteration 92
# Current loss value: 63776150.0
# Start of iteration 93
# Current loss value: 63446344.0
# Start of iteration 94
# Current loss value: 63133470.0
# Start of iteration 95
# Current loss value: 62846284.0
# Start of iteration 96
# Current loss value: 62504360.0
# Start of iteration 97
# Current loss value: 62156390.0
# Start of iteration 98
# Current loss value: 61978216.0
# Start of iteration 99
# Current loss value: 61761028.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_99.png
# Iteration 99 complited in 9s
# Start of iteration 100
# Current loss value: 61603990.0
# Start of iteration 101
# Current loss value: 61409060.0
# Start of iteration 102
# Current loss value: 61189796.0
# Start of iteration 103
# Current loss value: 60989276.0
# Start of iteration 104
# Current loss value: 60832870.0
# Start of iteration 105
# Current loss value: 60590730.0
# Start of iteration 106
# Current loss value: 60355450.0
# Start of iteration 107
# Current loss value: 60201572.0
# Start of iteration 108
# Current loss value: 60061388.0
# Start of iteration 109
# Current loss value: 59914610.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_109.png
# Iteration 109 complited in 9s
# Start of iteration 110
# Current loss value: 59750120.0
# Start of iteration 111
# Current loss value: 59624908.0
# Start of iteration 112
# Current loss value: 59475190.0
# Start of iteration 113
# Current loss value: 59306580.0
# Start of iteration 114
# Current loss value: 59168236.0
# Start of iteration 115
# Current loss value: 59015492.0
# Start of iteration 116
# Current loss value: 58852668.0
# Start of iteration 117
# Current loss value: 58689890.0
# Start of iteration 118
# Current loss value: 58529204.0
# Start of iteration 119
# Current loss value: 58379812.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_119.png
# Iteration 119 complited in 9s
# Start of iteration 120
# Current loss value: 58200160.0
# Start of iteration 121
# Current loss value: 58041124.0
# Start of iteration 122
# Current loss value: 57907564.0
# Start of iteration 123
# Current loss value: 57775660.0
# Start of iteration 124
# Current loss value: 57601144.0
# Start of iteration 125
# Current loss value: 57435244.0
# Start of iteration 126
# Current loss value: 57298740.0
# Start of iteration 127
# Current loss value: 57168228.0
# Start of iteration 128
# Current loss value: 57047692.0
# Start of iteration 129
# Current loss value: 56910410.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_129.png
# Iteration 129 complited in 9s
# Start of iteration 130
# Current loss value: 56793550.0
# Start of iteration 131
# Current loss value: 56677864.0
# Start of iteration 132
# Current loss value: 56551540.0
# Start of iteration 133
# Current loss value: 56430972.0
# Start of iteration 134
# Current loss value: 56332440.0
# Start of iteration 135
# Current loss value: 56226012.0
# Start of iteration 136
# Current loss value: 56104064.0
# Start of iteration 137
# Current loss value: 56002052.0
# Start of iteration 138
# Current loss value: 55890050.0
# Start of iteration 139
# Current loss value: 55793190.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_139.png
# Iteration 139 complited in 9s
# Start of iteration 140
# Current loss value: 55691056.0
# Start of iteration 141
# Current loss value: 55582316.0
# Start of iteration 142
# Current loss value: 55468916.0
# Start of iteration 143
# Current loss value: 55370270.0
# Start of iteration 144
# Current loss value: 55241016.0
# Start of iteration 145
# Current loss value: 55100896.0
# Start of iteration 146
# Current loss value: 54970388.0
# Start of iteration 147
# Current loss value: 54852664.0
# Start of iteration 148
# Current loss value: 54746750.0
# Start of iteration 149
# Current loss value: 54640884.0
# Image saved as /content/drive/My Drive/colab_notebooks/Keras_Fast_Style_Transfer/img_gen/picture/result_at_iteration_149.png
# Iteration 149 complited in 9s
